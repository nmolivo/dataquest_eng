# %% [markdown]
# ### Optimizing Postgres Databases: Exploring Postgres Internals
# #### These are exercises done as part of <a href = "www.dataquest.io"> DataQuest</a>'s Data Engineer Path
# This is not replicated for commercial use; strictly personal development.<br>
# All exercises are (c) DataQuest, with slight modifications so they use my PostGres server on my localhost

# %% [markdown]
# > We learn about Postgres schemas and how to build a database description from scratch. Using internal tables, we were able to describe metadata associated with our Postgres database. The metadata included data types, table names, created schemas, and plenty of other useful information.
# >
# >DataQuest

# %% [markdown]
# #### Exploring Postgres Internals Mission
# <b>1.  </b>Instructions:
# - Import the `psycopg2` library.
# - Connect to the `dq` database with the user `hud_admin` and the password `eRqg123EEkl` using the keyword arguments.
# - Use the `print` function to display the Connection object.

# %%
import psycopg2
conn = psycopg2.connect(dbname="valenbisi2018", user="stormadmin", password="admin123")
print(conn)
# Out:
# <connection object at 0x1061afe60; dsn: 'dbname=valenbisi2018 password=xxx user=stormadmin', closed: 0>

# %% [markdown]
# <font color = 'blue'>This seems to let any user get into any db, and it allows any password to fly. Resources to fix this:</font><br>
# - https://stackoverflow.com/questions/21054549/postgres-accepts-any-password
# - https://dba.stackexchange.com/questions/17790/created-user-can-access-all-databases-in-postgresql-without-any-grants

# %% [markdown]
# <b>2.  </b>Instructions:
# - Use the provided `cur` object.
# - Using the `SELECT` query, grab the `table_name` column from the `information_schema.tables` table with the `ORDER BY` option on the `table_name` column.
# - Fetch all the results and assign them to the variable `table_names`.
# - Loop through `table_names`:
# - Print each `table_name` from the query.

# %% [markdown]
# <font color = 'blue'>If you don't know the table names in your schema, you can fetch them by doing the following. Here is a list of tables in the `information_schema`:</font>
#
# >|Name|Data Type|Description|
# >|------|------|------|
# |`table_catalog`|`sql_identifier`|Name of the database that contains the table (always the current database)|
# |`table_schema`|`sql_identifier`|Name of the schema that contains the table|
# |`table_name`|`sql_identifier`|Name of the table|
# |`table_type`|`character_data`|Type of the table: BASE TABLE for a persistent base table (the normal table type), VIEW for a view, FOREIGN TABLE for a foreign table, or LOCAL TEMPORARY for a temporary table|
# |`self_referencing_column_name`|`sql_identifier`|Applies to a feature not available in PostgreSQL|
# |`reference_generation`|`character_data`|Applies to a feature not available in PostgreSQL|
# |`user_defined_type_catalog`|`sql_identifier`|If the table is a typed table, the name of the database that contains the underlying data type (always the current database), else null.|
# |`user_defined_type_schema`|`sql_identifier`|If the table is a typed table, the name of the schema that contains the underlying data type, else null.|
# |`user_defined_type_name`|`sql_identifier`|If the table is a typed table, the name of the underlying data type, else null.|
# |`is_insertable_into`|`yes_or_no`|YES if the table is insertable into, NO if not (Base tables are always insertable into, views not necessarily.)|
# |`is_typed`|`yes_or_no`|YES if the table is a typed table, NO if not|
# |`commit_action`|`character_data`|If the table is a temporary table, then PRESERVE, else null. (The SQL standard defines other commit actions for temporary tables, which are not supported by PostgreSQL.)|
# >
# ><a href = "https://www.postgresql.org/docs/9.1/static/infoschema-tables.html">PostgreSQL Documentation: Information Schema</a>

# %%
conn = psycopg2.connect(dbname="dq_exercises", user="nmolivo")
cur = conn.cursor()
cur.execute('SELECT table_name FROM information_schema.tables ORDER BY table_name')
table_names = cur.fetchall()
for name in table_names:
    print(name)
# Out:
# ('_pg_foreign_data_wrappers',)
# ('_pg_foreign_servers',)
# ('_pg_foreign_table_columns',)
# ('_pg_foreign_tables',)
# ('_pg_user_mappings',)
# ('administrable_role_authorizations',)
# ('applicable_roles',)
# ('attributes',)
# ('character_sets',)
# ('check_constraint_routine_usage',)
# ('check_constraints',)
# ('collation_character_set_applicability',)
# ('collations',)
# ('column_domain_usage',)
# ('column_options',)
# ('column_privileges',)
# ('column_udt_usage',)
# ('columns',)
# ('constraint_column_usage',)
# ('constraint_table_usage',)
# ('data_type_privileges',)
# ('domain_constraints',)
# ('domain_udt_usage',)
# ('domains',)
# ('element_types',)
# ('enabled_roles',)
# ('foreign_data_wrapper_options',)
# ('foreign_data_wrappers',)
# ('foreign_server_options',)
# ('foreign_servers',)
# ('foreign_table_options',)
# ('foreign_tables',)
# ('information_schema_catalog_name',)
# ('key_column_usage',)
# ('parameters',)
# ('pg_aggregate',)
# ('pg_am',)
# ('pg_amop',)
# ('pg_amproc',)
# ('pg_attrdef',)
# ('pg_attribute',)
# ('pg_auth_members',)
# ('pg_authid',)
# ('pg_available_extension_versions',)
# ('pg_available_extensions',)
# ('pg_cast',)
# ('pg_class',)
# ('pg_collation',)
# ('pg_config',)
# ('pg_constraint',)
# ('pg_conversion',)
# ('pg_cursors',)
# ('pg_database',)
# ('pg_db_role_setting',)
# ('pg_default_acl',)
# ('pg_depend',)
# ('pg_description',)
# ('pg_enum',)
# ('pg_event_trigger',)
# ('pg_extension',)
# ('pg_file_settings',)
# ('pg_foreign_data_wrapper',)
# ('pg_foreign_server',)
# ('pg_foreign_table',)
# ('pg_group',)
# ('pg_hba_file_rules',)
# ('pg_index',)
# ('pg_indexes',)
# ('pg_inherits',)
# ('pg_init_privs',)
# ('pg_language',)
# ('pg_largeobject',)
# ('pg_largeobject_metadata',)
# ('pg_locks',)
# ('pg_matviews',)
# ('pg_namespace',)
# ('pg_opclass',)
# ('pg_operator',)
# ('pg_opfamily',)
# ('pg_partitioned_table',)
# ('pg_pltemplate',)
# ('pg_policies',)
# ('pg_policy',)
# ('pg_prepared_statements',)
# ('pg_prepared_xacts',)
# ('pg_proc',)
# ('pg_publication',)
# ('pg_publication_rel',)
# ('pg_publication_tables',)
# ('pg_range',)
# ('pg_replication_origin',)
# ('pg_replication_origin_status',)
# ('pg_replication_slots',)
# ('pg_rewrite',)
# ('pg_roles',)
# ('pg_rules',)
# ('pg_seclabel',)
# ('pg_seclabels',)
# ('pg_sequence',)
# ('pg_sequences',)
# ('pg_settings',)
# ('pg_shadow',)
# ('pg_shdepend',)
# ('pg_shdescription',)
# ('pg_shseclabel',)
# ('pg_stat_activity',)
# ('pg_stat_all_indexes',)
# ('pg_stat_all_tables',)
# ('pg_stat_archiver',)
# ('pg_stat_bgwriter',)
# ('pg_stat_database',)
# ('pg_stat_database_conflicts',)
# ('pg_stat_progress_vacuum',)
# ('pg_stat_replication',)
# ('pg_stat_ssl',)
# ('pg_stat_subscription',)
# ('pg_stat_sys_indexes',)
# ('pg_stat_sys_tables',)
# ('pg_stat_user_functions',)
# ('pg_stat_user_indexes',)
# ('pg_stat_user_tables',)
# ('pg_stat_wal_receiver',)
# ('pg_stat_xact_all_tables',)
# ('pg_stat_xact_sys_tables',)
# ('pg_stat_xact_user_functions',)
# ('pg_stat_xact_user_tables',)
# ('pg_statio_all_indexes',)
# ('pg_statio_all_sequences',)
# ('pg_statio_all_tables',)
# ('pg_statio_sys_indexes',)
# ('pg_statio_sys_sequences',)
# ('pg_statio_sys_tables',)
# ('pg_statio_user_indexes',)
# ('pg_statio_user_sequences',)
# ('pg_statio_user_tables',)
# ('pg_statistic',)
# ('pg_statistic_ext',)
# ('pg_stats',)
# ('pg_subscription',)
# ('pg_subscription_rel',)
# ('pg_tables',)
# ('pg_tablespace',)
# ('pg_timezone_abbrevs',)
# ('pg_timezone_names',)
# ('pg_transform',)
# ('pg_trigger',)
# ('pg_ts_config',)
# ('pg_ts_config_map',)
# ('pg_ts_dict',)
# ('pg_ts_parser',)
# ('pg_ts_template',)
# ('pg_type',)
# ('pg_user',)
# ('pg_user_mapping',)
# ('pg_user_mappings',)
# ('pg_views',)
# ('referential_constraints',)
# ('role_column_grants',)
# ('role_routine_grants',)
# ('role_table_grants',)
# ('role_udt_grants',)
# ('role_usage_grants',)
# ('routine_privileges',)
# ('routines',)
# ('schemata',)
# ('sequences',)
# ('sql_features',)
# ('sql_implementation_info',)
# ('sql_languages',)
# ('sql_packages',)
# ('sql_parts',)
# ('sql_sizing',)
# ('sql_sizing_profiles',)
# ('stormdata',)
# ('table_constraints',)
# ('table_privileges',)
# ('tables',)
# ('transforms',)
# ('triggered_update_columns',)
# ('triggers',)
# ('udt_privileges',)
# ('usage_privileges',)
# ('user_defined_types',)
# ('user_mapping_options',)
# ('user_mappings',)
# ('view_column_usage',)
# ('view_routine_usage',)
# ('view_table_usage',)
# ('views',)

# %% [markdown]
# > In the output, you would have noticed many tables that started with the prefix `pg_*`. Each one of these tables is part of the `pg_catalog` group of internal tables. These are the system catalog tables.
# >
# > DataQuest

# %% [markdown]
# <b>3.  </b>Instructions:
# - Use the provided `cur` object.
# - Using the `SELECT` query, grab the `table_name` column from the `information_schema.tables` table.
#     - Find user created by filtering the query on the `table_schema` column.
#     - `ORDER BY` the `table_name` again.
# - Loop through `cur.fetchall()` and print each `table_name` from the query.

# %% [markdown]
# > In Postgres, schemas are used as a namespace for tables, with the distinct purpose of seperating them into isolated groups or sets within a single database.
# >
# > DataQuest

# %%
cur = conn.cursor()
conn = psycopg2.connect(dbname="dq_exercises", user="nmolivo")
cur = conn.cursor()
cur.execute("SELECT table_name FROM information_schema.tables WHERE table_schema='public' ORDER BY table_name")
table_names = cur.fetchall()
for table_name in cur.fetchall():
    name = table_name[0]
    print(name)

# %% [markdown]
# <b>4.  </b>Instructions:
# - Import `AsIs` from `psycopg2.extensions`.
# - Within the loop for `cur.fetchall()` for each table name:
#     - Run a `SELECT` query with the table variable using `AsIs`.
#     - Print the `cur.description` attribute.
#     - Print a black space to seperate the descriptions at the end of each loop.

# %%
from psycopg2.extensions import AsIs

conn = psycopg2.connect(dbname="dq_exercises", user="nmolivo")
cur = conn.cursor()
cur.execute("SELECT table_name FROM information_schema.tables WHERE table_schema='public'")
for table in cur.fetchall(): 
     table = table[0]
     cur.execute("SELECT * FROM %s LIMIT 0", [AsIs(table)])
     print(cur.description, "\n")
# Out:
# (Column(name='fid', type_code=1043, display_size=None, internal_size=32, precision=None, scale=None, null_ok=None), Column(name='btid', type_code=1042, display_size=None, internal_size=4, precision=None, scale=None, null_ok=None), Column(name='name', type_code=1042, display_size=None, internal_size=9, precision=None, scale=None, null_ok=None), Column(name='lat', type_code=1700, display_size=None, internal_size=4, precision=4, scale=2, null_ok=None), Column(name='long', type_code=1700, display_size=None, internal_size=7, precision=7, scale=4, null_ok=None), Column(name='wind_kts', type_code=23, display_size=None, internal_size=4, precision=None, scale=None, null_ok=None), Column(name='pressure', type_code=23, display_size=None, internal_size=4, precision=None, scale=None, null_ok=None), Column(name='cat', type_code=1042, display_size=None, internal_size=2, precision=None, scale=None, null_ok=None), Column(name='basin', type_code=1042, display_size=None, internal_size=15, precision=None, scale=None, null_ok=None), Column(name='shape_len', type_code=1700, display_size=None, internal_size=9, precision=9, scale=7, null_ok=None), Column(name='date', type_code=1114, display_size=None, internal_size=8, precision=None, scale=None, null_ok=None))

# %% [markdown]
# <b>5.  </b>Instructions:
# - Use the provided `cur` object.
# - Using `execute()`, `SELECT` from the `pg_catalog.pg_type`, choose two columns that can map an integer type code to a human - readable string.
# - Create a dict and assign it to the variable `type_mappings`.
# - Loop through the returned `SELECT` query and map the integer type code to the string.

# %%
conn = psycopg2.connect(dbname="dq_exercises", user="nmolivo")
cur = conn.cursor()
cur.execute("SELECT oid, typname FROM pg_catalog.pg_type")
type_mappings = {
    int(oid): typname
    for oid, typname in cur.fetchall()
}

# %% [markdown]
# >One interesting thing to note about <a href = "https://www.postgresql.org/docs/9.6/static/catalog-pg-type.html">`pg_catalog.pg_type`</a> is that it can be used to create your own Postgres types from scratch.
# >
# >DataQuest

# %%
type_mappings
# Out:
# {16: 'bool',
#  17: 'bytea',
#  18: 'char',
#  19: 'name',
#  20: 'int8',
#  21: 'int2',
#  22: 'int2vector',
#  23: 'int4',
#  24: 'regproc',
#  25: 'text',
#  26: 'oid',
#  27: 'tid',
#  28: 'xid',
#  29: 'cid',
#  30: 'oidvector',
#  32: 'pg_ddl_command',
#  71: 'pg_type',
#  75: 'pg_attribute',
#  81: 'pg_proc',
#  83: 'pg_class',
#  114: 'json',
#  142: 'xml',
#  143: '_xml',
#  194: 'pg_node_tree',
#  199: '_json',
#  210: 'smgr',
#  325: 'index_am_handler',
#  600: 'point',
#  601: 'lseg',
#  602: 'path',
#  603: 'box',
#  604: 'polygon',
#  628: 'line',
#  629: '_line',
#  650: 'cidr',
#  651: '_cidr',
#  700: 'float4',
#  701: 'float8',
#  702: 'abstime',
#  703: 'reltime',
#  704: 'tinterval',
#  705: 'unknown',
#  718: 'circle',
#  719: '_circle',
#  774: 'macaddr8',
#  775: '_macaddr8',
#  790: 'money',
#  791: '_money',
#  829: 'macaddr',
#  869: 'inet',
#  1000: '_bool',
#  1001: '_bytea',
#  1002: '_char',
#  1003: '_name',
#  1005: '_int2',
#  1006: '_int2vector',
#  1007: '_int4',
#  1008: '_regproc',
#  1009: '_text',
#  1010: '_tid',
#  1011: '_xid',
#  1012: '_cid',
#  1013: '_oidvector',
#  1014: '_bpchar',
#  1015: '_varchar',
#  1016: '_int8',
#  1017: '_point',
#  1018: '_lseg',
#  1019: '_path',
#  1020: '_box',
#  1021: '_float4',
#  1022: '_float8',
#  1023: '_abstime',
#  1024: '_reltime',
#  1025: '_tinterval',
#  1027: '_polygon',
#  1028: '_oid',
#  1033: 'aclitem',
#  1034: '_aclitem',
#  1040: '_macaddr',
#  1041: '_inet',
#  1042: 'bpchar',
#  1043: 'varchar',
#  1082: 'date',
#  1083: 'time',
#  1114: 'timestamp',
#  1115: '_timestamp',
#  1182: '_date',
#  1183: '_time',
#  1184: 'timestamptz',
#  1185: '_timestamptz',
#  1186: 'interval',
#  1187: '_interval',
#  1231: '_numeric',
#  1248: 'pg_database',
#  1263: '_cstring',
#  1266: 'timetz',
#  1270: '_timetz',
#  1560: 'bit',
#  1561: '_bit',
#  1562: 'varbit',
#  1563: '_varbit',
#  1700: 'numeric',
#  1790: 'refcursor',
#  2201: '_refcursor',
#  2202: 'regprocedure',
#  2203: 'regoper',
#  2204: 'regoperator',
#  2205: 'regclass',
#  2206: 'regtype',
#  2207: '_regprocedure',
#  2208: '_regoper',
#  2209: '_regoperator',
#  2210: '_regclass',
#  2211: '_regtype',
#  2249: 'record',
#  2275: 'cstring',
#  2276: 'any',
#  2277: 'anyarray',
#  2278: 'void',
#  2279: 'trigger',
#  2280: 'language_handler',
#  2281: 'internal',
#  2282: 'opaque',
#  2283: 'anyelement',
#  2287: '_record',
#  2776: 'anynonarray',
#  2842: 'pg_authid',
#  2843: 'pg_auth_members',
#  2949: '_txid_snapshot',
#  2950: 'uuid',
#  2951: '_uuid',
#  2970: 'txid_snapshot',
#  3115: 'fdw_handler',
#  3220: 'pg_lsn',
#  3221: '_pg_lsn',
#  3310: 'tsm_handler',
#  3361: 'pg_ndistinct',
#  3402: 'pg_dependencies',
#  3500: 'anyenum',
#  3614: 'tsvector',
#  3615: 'tsquery',
#  3642: 'gtsvector',
#  3643: '_tsvector',
#  3644: '_gtsvector',
#  3645: '_tsquery',
#  3734: 'regconfig',
#  3735: '_regconfig',
#  3769: 'regdictionary',
#  3770: '_regdictionary',
#  3802: 'jsonb',
#  3807: '_jsonb',
#  3831: 'anyrange',
#  3838: 'event_trigger',
#  3904: 'int4range',
#  3905: '_int4range',
#  3906: 'numrange',
#  3907: '_numrange',
#  3908: 'tsrange',
#  3909: '_tsrange',
#  3910: 'tstzrange',
#  3911: '_tstzrange',
#  3912: 'daterange',
#  3913: '_daterange',
#  3926: 'int8range',
#  3927: '_int8range',
#  4066: 'pg_shseclabel',
#  4089: 'regnamespace',
#  4090: '_regnamespace',
#  4096: 'regrole',
#  4097: '_regrole',
#  6101: 'pg_subscription',
#  10000: 'pg_attrdef',
#  10001: 'pg_constraint',
#  10002: 'pg_inherits',
#  10003: 'pg_index',
#  10004: 'pg_operator',
#  10005: 'pg_opfamily',
#  10006: 'pg_opclass',
#  10130: 'pg_am',
#  10131: 'pg_amop',
#  10841: 'pg_amproc',
#  11253: 'pg_language',
#  11254: 'pg_largeobject_metadata',
#  11255: 'pg_largeobject',
#  11256: 'pg_aggregate',
#  11257: 'pg_statistic_ext',
#  11258: 'pg_statistic',
#  11259: 'pg_rewrite',
#  11260: 'pg_trigger',
#  11261: 'pg_event_trigger',
#  11262: 'pg_description',
#  11263: 'pg_cast',
#  11483: 'pg_enum',
#  11484: 'pg_namespace',
#  11485: 'pg_conversion',
#  11486: 'pg_depend',
#  11487: 'pg_db_role_setting',
#  11488: 'pg_tablespace',
#  11489: 'pg_pltemplate',
#  11490: 'pg_shdepend',
#  11491: 'pg_shdescription',
#  11492: 'pg_ts_config',
#  11493: 'pg_ts_config_map',
#  11494: 'pg_ts_dict',
#  11495: 'pg_ts_parser',
#  11496: 'pg_ts_template',
#  11497: 'pg_extension',
#  11498: 'pg_foreign_data_wrapper',
#  11499: 'pg_foreign_server',
#  11500: 'pg_user_mapping',
#  11501: 'pg_foreign_table',
#  11502: 'pg_policy',
#  11503: 'pg_replication_origin',
#  11504: 'pg_default_acl',
#  11505: 'pg_init_privs',
#  11506: 'pg_seclabel',
#  11507: 'pg_collation',
#  11508: 'pg_partitioned_table',
#  11509: 'pg_range',
#  11510: 'pg_transform',
#  11511: 'pg_sequence',
#  11512: 'pg_publication',
#  11513: 'pg_publication_rel',
#  11514: 'pg_subscription_rel',
#  11515: 'pg_toast_2604',
#  11516: 'pg_toast_2606',
#  11517: 'pg_toast_2609',
#  11518: 'pg_toast_1255',
#  11519: 'pg_toast_2618',
#  11520: 'pg_toast_3596',
#  11521: 'pg_toast_2619',
#  11522: 'pg_toast_3381',
#  11523: 'pg_toast_2620',
#  11524: 'pg_toast_2396',
#  11525: 'pg_toast_2964',
#  11526: 'pg_toast_3592',
#  11528: 'pg_roles',
#  11532: 'pg_shadow',
#  11536: 'pg_group',
#  11539: 'pg_user',
#  11542: 'pg_policies',
#  11546: 'pg_rules',
#  11550: 'pg_views',
#  11554: 'pg_tables',
#  11558: 'pg_matviews',
#  11562: 'pg_indexes',
#  11566: 'pg_sequences',
#  11570: 'pg_stats',
#  11574: 'pg_publication_tables',
#  11578: 'pg_locks',
#  11581: 'pg_cursors',
#  11584: 'pg_available_extensions',
#  11587: 'pg_available_extension_versions',
#  11590: 'pg_prepared_xacts',
#  11594: 'pg_prepared_statements',
#  11597: 'pg_seclabels',
#  11601: 'pg_settings',
#  11606: 'pg_file_settings',
#  11609: 'pg_hba_file_rules',
#  11612: 'pg_timezone_abbrevs',
#  11615: 'pg_timezone_names',
#  11618: 'pg_config',
#  11621: 'pg_stat_all_tables',
#  11625: 'pg_stat_xact_all_tables',
#  11629: 'pg_stat_sys_tables',
#  11633: 'pg_stat_xact_sys_tables',
#  11636: 'pg_stat_user_tables',
#  11640: 'pg_stat_xact_user_tables',
#  11643: 'pg_statio_all_tables',
#  11647: 'pg_statio_sys_tables',
#  11650: 'pg_statio_user_tables',
#  11653: 'pg_stat_all_indexes',
#  11657: 'pg_stat_sys_indexes',
#  11660: 'pg_stat_user_indexes',
#  11663: 'pg_statio_all_indexes',
#  11667: 'pg_statio_sys_indexes',
#  11670: 'pg_statio_user_indexes',
#  11673: 'pg_statio_all_sequences',
#  11677: 'pg_statio_sys_sequences',
#  11680: 'pg_statio_user_sequences',
#  11683: 'pg_stat_activity',
#  11687: 'pg_stat_replication',
#  11691: 'pg_stat_wal_receiver',
#  11694: 'pg_stat_subscription',
#  11697: 'pg_stat_ssl',
#  11700: 'pg_replication_slots',
#  11704: 'pg_stat_database',
#  11707: 'pg_stat_database_conflicts',
#  11710: 'pg_stat_user_functions',
#  11714: 'pg_stat_xact_user_functions',
#  11718: 'pg_stat_archiver',
#  11721: 'pg_stat_bgwriter',
#  11724: 'pg_stat_progress_vacuum',
#  11728: 'pg_user_mappings',
#  11732: 'pg_replication_origin_status',
#  12989: 'cardinal_number',
#  12991: 'character_data',
#  12992: 'sql_identifier',
#  12994: 'information_schema_catalog_name',
#  12996: 'time_stamp',
#  12997: 'yes_or_no',
#  13000: 'applicable_roles',
#  13004: 'administrable_role_authorizations',
#  13007: 'attributes',
#  13011: 'character_sets',
#  13015: 'check_constraint_routine_usage',
#  13019: 'check_constraints',
#  13023: 'collations',
#  13027: 'collation_character_set_applicability',
#  13031: 'column_domain_usage',
#  13035: 'column_privileges',
#  13039: 'column_udt_usage',
#  13043: 'columns',
#  13047: 'constraint_column_usage',
#  13051: 'constraint_table_usage',
#  13055: 'domain_constraints',
#  13059: 'domain_udt_usage',
#  13063: 'domains',
#  13067: 'enabled_roles',
#  13070: 'key_column_usage',
#  13074: 'parameters',
#  13078: 'referential_constraints',
#  13082: 'role_column_grants',
#  13085: 'routine_privileges',
#  13089: 'role_routine_grants',
#  13092: 'routines',
#  13096: 'schemata',
#  13099: 'sequences',
#  13103: 'sql_features',
#  13105: 'pg_toast_13102',
#  13108: 'sql_implementation_info',
#  13110: 'pg_toast_13107',
#  13113: 'sql_languages',
#  13115: 'pg_toast_13112',
#  13118: 'sql_packages',
#  13120: 'pg_toast_13117',
#  13123: 'sql_parts',
#  13125: 'pg_toast_13122',
#  13128: 'sql_sizing',
#  13130: 'pg_toast_13127',
#  13133: 'sql_sizing_profiles',
#  13135: 'pg_toast_13132',
#  13138: 'table_constraints',
#  13142: 'table_privileges',
#  13146: 'role_table_grants',
#  13149: 'tables',
#  13153: 'transforms',
#  13157: 'triggered_update_columns',
#  13161: 'triggers',
#  13165: 'udt_privileges',
#  13169: 'role_udt_grants',
#  13172: 'usage_privileges',
#  13176: 'role_usage_grants',
#  13179: 'user_defined_types',
#  13183: 'view_column_usage',
#  13187: 'view_routine_usage',
#  13191: 'view_table_usage',
#  13195: 'views',
#  13199: 'data_type_privileges',
#  13203: 'element_types',
#  13207: '_pg_foreign_table_columns',
#  13211: 'column_options',
#  13214: '_pg_foreign_data_wrappers',
#  13217: 'foreign_data_wrapper_options',
#  13220: 'foreign_data_wrappers',
#  13223: '_pg_foreign_servers',
#  13227: 'foreign_server_options',
#  13230: 'foreign_servers',
#  13233: '_pg_foreign_tables',
#  13237: 'foreign_table_options',
#  13240: 'foreign_tables',
#  13243: '_pg_user_mappings',
#  13247: 'user_mapping_options',
#  13251: 'user_mappings',
#  16627: '_stormdata',
#  16628: 'stormdata'}

# %% [markdown]
# >Let's put all this together and create our own table descriptions. We want to rewrite the description attributes from a list of tuples towards something human readable. In the following exercise, we will assemble output from the previous exercises into a dictionary.
# >
# >DataQuest
#
# <b>6.  </b>Instructions:
# - Use the provided `cur`, `type_mappings`, and `table_names` objects.
# - Create a dict and assign it to the variable `readable_description`.
# - Loop through the `table_names` with the table variable and do the following:
#     - Get the description attribute for the given table.
#     - Map the name of the table to a dictionary with a columns key.
#     - Recreate the columns list from the screen example by iterating through the description, and mapping the appropriate types.
# - Print the `readable_description` dictionary at the end.

# %%
from psycopg2.extensions import AsIs
conn = psycopg2.connect(dbname="dq_exercises", user="nmolivo")
cur = conn.cursor()
# You have `table_names` and `type_mappings` provided for you.

readable_description = {}
#for table in table_names:
    #cur.execute("SELECT * FROM %s LIMIT 0", [AsIs(table)])
cur.execute("SELECT * FROM stormdata LIMIT 0")
readable_description[table] = dict(
    columns=[
        dict(
            name=col.name,
            type=type_mappings[col.type_code],
            length=col.internal_size
        )
        for col in cur.description
    ]
)
print(readable_description)
# Out:
# {('stormdata',): {'columns': [{'length': 32, 'name': 'fid', 'type': 'varchar'}, {'length': 4, 'name': 'btid', 'type': 'bpchar'}, {'length': 9, 'name': 'name', 'type': 'bpchar'}, {'length': 4, 'name': 'lat', 'type': 'numeric'}, {'length': 7, 'name': 'long', 'type': 'numeric'}, {'length': 4, 'name': 'wind_kts', 'type': 'int4'}, {'length': 4, 'name': 'pressure', 'type': 'int4'}, {'length': 2, 'name': 'cat', 'type': 'bpchar'}, {'length': 15, 'name': 'basin', 'type': 'bpchar'}, {'length': 9, 'name': 'shape_len', 'type': 'numeric'}, {'length': 8, 'name': 'date', 'type': 'timestamp'}]}}

# %% [markdown]
# > Let's provide our description with the number of rows in the table.
# >
# > DataQuest
#
# <b>7.  </b>Instructions:
# - Use the provided `cur` object and `AsIs` class.
# - Loop through the `readable_description` keys:
#     - Fetch the value of each table's row count and assign it to a `total` key for that table.
# - Print the `readable_description` dictionary at the end.

# %%
from psycopg2.extensions import AsIs
conn = psycopg2.connect(dbname="dq_exercises", user="nmolivo")
cur = conn.cursor()

#for table in readable_description.keys():
    #cur.execute("SELECT COUNT(*) FROM %s", [AsIs(table)])
cur.execute("SELECT COUNT(*) FROM stormdata")
readable_description[table]["total"] = cur.fetchone()

# %%
readable_description
# Out:
# {('stormdata',): {'columns': [{'length': 32, 'name': 'fid', 'type': 'varchar'},
#    {'length': 4, 'name': 'btid', 'type': 'bpchar'},
#    {'length': 9, 'name': 'name', 'type': 'bpchar'},
#    {'length': 4, 'name': 'lat', 'type': 'numeric'},
#    {'length': 7, 'name': 'long', 'type': 'numeric'},
#    {'length': 4, 'name': 'wind_kts', 'type': 'int4'},
#    {'length': 4, 'name': 'pressure', 'type': 'int4'},
#    {'length': 2, 'name': 'cat', 'type': 'bpchar'},
#    {'length': 15, 'name': 'basin', 'type': 'bpchar'},
#    {'length': 9, 'name': 'shape_len', 'type': 'numeric'},
#    {'length': 8, 'name': 'date', 'type': 'timestamp'}],
#   'total': (118456,)}}

# %% [markdown]
# >Finally, let's add some sample rows the readable_description dictionary.
# >
# >DataQuest
#
# <b>8.  </b>Instructions:
# - Use the provided `cur` object and `AsIs` class.
# - Loop through the `readable_description` keys and run the following:
#     - Select the first 100 rows with `SELECT ... LIMIT` using `execute()` and `AsIs`.
#     - Fetch the all the rows and assign it to the `readable_description` dictionary for the given table using the `sample_rows` key.
# - Print the `readable_description` dictionary at the end.

# %%
from psycopg2.extensions import AsIs
conn = psycopg2.connect(dbname="dq_exercises", user="nmolivo")
cur = conn.cursor()

#for table in readable_description.keys():
#    cur.execute("SELECT * FROM %s LIMIT 100", [AsIs(table)])
cur.execute("SELECT * FROM stormdata LIMIT 100")
readable_description[table]["sample_rows"] = cur.fetchall()

# %%
readable_description
# Out:
# {('stormdata',): {'columns': [{'length': 32, 'name': 'fid', 'type': 'varchar'},
#    {'length': 4, 'name': 'btid', 'type': 'bpchar'},
#    {'length': 9, 'name': 'name', 'type': 'bpchar'},
#    {'length': 4, 'name': 'lat', 'type': 'numeric'},
#    {'length': 7, 'name': 'long', 'type': 'numeric'},
#    {'length': 4, 'name': 'wind_kts', 'type': 'int4'},
#    {'length': 4, 'name': 'pressure', 'type': 'int4'},
#    {'length': 2, 'name': 'cat', 'type': 'bpchar'},
#    {'length': 15, 'name': 'basin', 'type': 'bpchar'},
#    {'length': 9, 'name': 'shape_len', 'type': 'numeric'},
#    {'length': 8, 'name': 'date', 'type': 'timestamp'}],
#   'sample_rows': [('2001',
#     '63  ',
#     'NOTNAMED ',
#     Decimal('22.50'),
#     Decimal('-140.0000'),
#     50,
#     0,
#     'TS',
#     'Eastern Pacific',
#     Decimal('1.1401750'),
#     datetime.datetime(1957, 8, 8, 0, 0)),
#    ('2002',
#     '116 ',
#     'PAULINE  ',
#     Decimal('22.10'),
#     Decimal('-140.2000'),
#     45,
#     0,
#     'TS',
#     'Eastern Pacific',
#     Decimal('1.1661900'),
#     datetime.datetime(1961, 10, 3, 0, 0)),
#    ('2003',
#     '124 ',
#     'C        ',
#     Decimal('18.00'),
#     Decimal('-140.0000'),
#     45,
#     0,
#     'TS',
#     'Eastern Pacific',
#     Decimal('2.1023800'),
#     datetime.datetime(1962, 8, 29, 0, 0)),
#    ('2004',
#     '168 ',
#     'DENISE   ',
#     Decimal('16.60'),
#     Decimal('-139.5000'),
#     45,
#     0,
#     'TS',
#     'Eastern Pacific',
#     Decimal('2.1213200'),
#     datetime.datetime(1967, 7, 14, 0, 0)),
#    ('2005',
#     '251 ',
#     'DIANA    ',
#     Decimal('18.50'),
#     Decimal('-139.8000'),
#     70,
#     0,
#     'H1',
#     'Eastern Pacific',
#     Decimal('1.7029390'),
#     datetime.datetime(1972, 8, 16, 0, 0)),
#    ('2006',
#     '312 ',
#     'DIANA    ',
#     Decimal('18.60'),
#     Decimal('-139.8000'),
#     30,
#     0,
#     'TD',
#     'Eastern Pacific',
#     Decimal('1.6000000'),
#     datetime.datetime(1976, 7, 22, 0, 0)),
#    ('2007',
#     '342 ',
#     'KRISTY   ',
#     Decimal('21.40'),
#     Decimal('-140.2000'),
#     45,
#     0,
#     'TS',
#     'Eastern Pacific',
#     Decimal('1.3038400'),
#     datetime.datetime(1978, 8, 26, 0, 0)),
#    ('2008',
#     '371 ',
#     'KAY      ',
#     Decimal('20.50'),
#     Decimal('-140.2000'),
#     75,
#     0,
#     'H1',
#     'Eastern Pacific',
#     Decimal('1.2206560'),
#     datetime.datetime(1980, 9, 24, 0, 0)),
#    ('2009',
#     '223 ',
#     'MAGGIE   ',
#     Decimal('14.90'),
#     Decimal('-139.4000'),
#     45,
#     0,
#     'TS',
#     'Eastern Pacific',
#     Decimal('0.9219540'),
#     datetime.datetime(1970, 8, 23, 0, 0)),
#    ('2010',
#     '381 ',
#     'GREG     ',
#     Decimal('18.70'),
#     Decimal('-140.2000'),
#     45,
#     0,
#     'TS',
#     'Eastern Pacific',
#     Decimal('0.9219540'),
#     datetime.datetime(1981, 8, 21, 0, 0)),
#    ('2011',
#     '223 ',
#     'MAGGIE   ',
#     Decimal('15.10'),
#     Decimal('-140.3000'),
#     45,
#     0,
#     'TS',
#     'Eastern Pacific',
#     Decimal('0.9219540'),
#     datetime.datetime(1970, 8, 23, 0, 0)),
#    ('2012',
#     '384 ',
#     'JOVA     ',
#     Decimal('19.70'),
#     Decimal('-140.0000'),
#     60,
#     0,
#     'TS',
#     'Eastern Pacific',
#     Decimal('1.7464250'),
#     datetime.datetime(1981, 9, 18, 0, 0)),
#    ('2013',
#     '233 ',
#     'DENISE   ',
#     Decimal('14.00'),
#     Decimal('-135.7000'),
#     100,
#     0,
#     'H3',
#     'Eastern Pacific',
#     Decimal('1.6763050'),
#     datetime.datetime(1971, 7, 10, 0, 0)),
#    ('2014',
#     '393 ',
#     'DANIEL   ',
#     Decimal('18.10'),
#     Decimal('-140.0000'),
#     35,
#     0,
#     'TS',
#     'Eastern Pacific',
#     Decimal('1.6278820'),
#     datetime.datetime(1982, 7, 16, 0, 0)),
#    ('2015',
#     '437 ',
#     'DOUGLAS  ',
#     Decimal('18.10'),
#     Decimal('-140.0000'),
#     30,
#     0,
#     'TD',
#     'Eastern Pacific',
#     Decimal('1.3152950'),
#     datetime.datetime(1984, 7, 3, 0, 0)),
#    ('2016',
#     '522 ',
#     'HECTOR   ',
#     Decimal('18.60'),
#     Decimal('-140.0000'),
#     40,
#     1005,
#     'TS',
#     'Eastern Pacific',
#     Decimal('1.4035670'),
#     datetime.datetime(1988, 8, 9, 0, 0)),
#    ('2017',
#     '233 ',
#     'DENISE   ',
#     Decimal('14.50'),
#     Decimal('-137.3000'),
#     100,
#     0,
#     'H3',
#     'Eastern Pacific',
#     Decimal('1.9313210'),
#     datetime.datetime(1971, 7, 10, 0, 0)),
#    ('2018',
#     '534 ',
#     'ERICK    ',
#     Decimal('17.20'),
#     Decimal('-139.5000'),
#     30,
#     1012,
#     'TD',
#     'Eastern Pacific',
#     Decimal('2.7459060'),
#     datetime.datetime(1989, 7, 21, 0, 0)),
#    ('2019',
#     '250 ',
#     'CELESTE  ',
#     Decimal('15.40'),
#     Decimal('-137.5000'),
#     75,
#     0,
#     'H1',
#     'Eastern Pacific',
#     Decimal('0.8944270'),
#     datetime.datetime(1972, 8, 11, 0, 0)),
#    ('2020',
#     '590 ',
#     'GEORGETTE',
#     Decimal('17.50'),
#     Decimal('-139.4000'),
#     30,
#     1007,
#     'TD',
#     'Eastern Pacific',
#     Decimal('2.1023800'),
#     datetime.datetime(1992, 7, 24, 0, 0)),
#    ('2021',
#     '250 ',
#     'CELESTE  ',
#     Decimal('15.00'),
#     Decimal('-138.3000'),
#     75,
#     0,
#     'H1',
#     'Eastern Pacific',
#     Decimal('0.8062260'),
#     datetime.datetime(1972, 8, 11, 0, 0)),
#    ('2022',
#     '598 ',
#     'ORLENE   ',
#     Decimal('22.60'),
#     Decimal('-140.0000'),
#     40,
#     1002,
#     'TS',
#     'Eastern Pacific',
#     Decimal('1.5132750'),
#     datetime.datetime(1992, 9, 12, 0, 0)),
#    ('2023',
#     '607 ',
#     'YOLANDA  ',
#     Decimal('16.20'),
#     Decimal('-140.2000'),
#     25,
#     1011,
#     'TD',
#     'Eastern Pacific',
#     Decimal('1.6000000'),
#     datetime.datetime(1992, 10, 22, 0, 0)),
#    ('2024',
#     '250 ',
#     'CELESTE  ',
#     Decimal('14.60'),
#     Decimal('-139.0000'),
#     80,
#     0,
#     'H1',
#     'Eastern Pacific',
#     Decimal('0.8062260'),
#     datetime.datetime(1972, 8, 12, 0, 0)),
#    ('2025',
#     '613 ',
#     'EUGENE   ',
#     Decimal('19.20'),
#     Decimal('-139.8000'),
#     40,
#     997,
#     'TS',
#     'Eastern Pacific',
#     Decimal('2.2203600'),
#     datetime.datetime(1993, 7, 22, 0, 0)),
#    ('2026',
#     '250 ',
#     'CELESTE  ',
#     Decimal('14.20'),
#     Decimal('-139.7000'),
#     80,
#     0,
#     'H1',
#     'Eastern Pacific',
#     Decimal('0.8062260'),
#     datetime.datetime(1972, 8, 12, 0, 0)),
#    ('2027',
#     '250 ',
#     'CELESTE  ',
#     Decimal('13.80'),
#     Decimal('-140.4000'),
#     85,
#     0,
#     'H2',
#     'Eastern Pacific',
#     Decimal('1.0198040'),
#     datetime.datetime(1972, 8, 12, 0, 0)),
#    ('2028',
#     '615 ',
#     'FERNANDA ',
#     Decimal('18.30'),
#     Decimal('-139.6000'),
#     85,
#     973,
#     'H2',
#     'Eastern Pacific',
#     Decimal('1.6278820'),
#     datetime.datetime(1993, 8, 14, 0, 0)),
#    ('2029',
#     '250 ',
#     'CELESTE  ',
#     Decimal('13.60'),
#     Decimal('-141.4000'),
#     85,
#     0,
#     'H2',
#     'Eastern Pacific',
#     Decimal('1.2041590'),
#     datetime.datetime(1972, 8, 12, 0, 0)),
#    ('2030',
#     '635 ',
#     'KRISTY   ',
#     Decimal('16.20'),
#     Decimal('-139.8000'),
#     60,
#     992,
#     'TS',
#     'Eastern Pacific',
#     Decimal('1.5033300'),
#     datetime.datetime(1994, 8, 31, 0, 0)),
#    ('2031',
#     '250 ',
#     'CELESTE  ',
#     Decimal('13.50'),
#     Decimal('-142.6000'),
#     85,
#     0,
#     'H2',
#     'Eastern Pacific',
#     Decimal('1.3152950'),
#     datetime.datetime(1972, 8, 13, 0, 0)),
#    ('2032',
#     '636 ',
#     'LANE     ',
#     Decimal('21.40'),
#     Decimal('-140.0000'),
#     25,
#     1010,
#     'TD',
#     'Eastern Pacific',
#     Decimal('1.4035670'),
#     datetime.datetime(1994, 9, 10, 0, 0)),
#    ('2033',
#     '666 ',
#     'DOLORES  ',
#     Decimal('21.00'),
#     Decimal('-140.0000'),
#     30,
#     1008,
#     'TD',
#     'Eastern Pacific',
#     Decimal('1.4422210'),
#     datetime.datetime(1997, 7, 11, 0, 0)),
#    ('2034',
#     '272 ',
#     'KATHERINE',
#     Decimal('14.60'),
#     Decimal('-136.0000'),
#     50,
#     0,
#     'TS',
#     'Eastern Pacific',
#     Decimal('1.3341660'),
#     datetime.datetime(1973, 10, 6, 0, 0)),
#    ('2035',
#     '272 ',
#     'KATHERINE',
#     Decimal('14.30'),
#     Decimal('-137.3000'),
#     45,
#     0,
#     'TS',
#     'Eastern Pacific',
#     Decimal('1.4317820'),
#     datetime.datetime(1973, 10, 6, 0, 0)),
#    ('2036',
#     '698 ',
#     'DORA     ',
#     Decimal('15.50'),
#     Decimal('-139.7000'),
#     100,
#     960,
#     'H3',
#     'Eastern Pacific',
#     Decimal('2.0000000'),
#     datetime.datetime(1999, 8, 14, 0, 0)),
#    ('2037',
#     '272 ',
#     'KATHERINE',
#     Decimal('14.00'),
#     Decimal('-138.7000'),
#     45,
#     0,
#     'TS',
#     'Eastern Pacific',
#     Decimal('1.4317820'),
#     datetime.datetime(1973, 10, 6, 0, 0)),
#    ('2038',
#     '708 ',
#     'DANIEL   ',
#     Decimal('17.50'),
#     Decimal('-139.6000'),
#     90,
#     968,
#     'H2',
#     'Eastern Pacific',
#     Decimal('1.7720050'),
#     datetime.datetime(2000, 7, 28, 0, 0)),
#    ('2039',
#     '272 ',
#     'KATHERINE',
#     Decimal('13.70'),
#     Decimal('-140.1000'),
#     45,
#     0,
#     'TS',
#     'Eastern Pacific',
#     Decimal('1.5297060'),
#     datetime.datetime(1973, 10, 6, 0, 0)),
#    ('2040',
#     '724 ',
#     'BARBARA  ',
#     Decimal('16.80'),
#     Decimal('-140.1000'),
#     30,
#     1006,
#     'TD',
#     'Eastern Pacific',
#     Decimal('1.2083050'),
#     datetime.datetime(2001, 6, 22, 0, 0)),
#    ('2041',
#     '272 ',
#     'KATHERINE',
#     Decimal('13.40'),
#     Decimal('-141.6000'),
#     40,
#     0,
#     'TS',
#     'Eastern Pacific',
#     Decimal('0.8062260'),
#     datetime.datetime(1973, 10, 7, 0, 0)),
#    ('2042',
#     '272 ',
#     'KATHERINE',
#     Decimal('13.30'),
#     Decimal('-142.4000'),
#     40,
#     0,
#     'TS',
#     'Eastern Pacific',
#     Decimal('0.9055390'),
#     datetime.datetime(1973, 10, 7, 0, 0)),
#    ('2043',
#     '736 ',
#     'NARDA    ',
#     Decimal('16.30'),
#     Decimal('-139.6000'),
#     35,
#     1002,
#     'TS',
#     'Eastern Pacific',
#     Decimal('1.6031220'),
#     datetime.datetime(2001, 10, 23, 0, 0)),
#    ('2044',
#     '282 ',
#     'IONE     ',
#     Decimal('12.40'),
#     Decimal('-135.6000'),
#     30,
#     0,
#     'TD',
#     'Eastern Pacific',
#     Decimal('1.0049880'),
#     datetime.datetime(1974, 8, 23, 0, 0)),
#    ('2045',
#     '759 ',
#     'GUILLERMO',
#     Decimal('16.30'),
#     Decimal('-139.8000'),
#     25,
#     1008,
#     'L ',
#     'Eastern Pacific',
#     Decimal('1.7117240'),
#     datetime.datetime(2003, 8, 12, 0, 0)),
#    ('2046',
#     '282 ',
#     'IONE     ',
#     Decimal('12.30'),
#     Decimal('-136.6000'),
#     30,
#     0,
#     'TD',
#     'Eastern Pacific',
#     Decimal('1.0049880'),
#     datetime.datetime(1974, 8, 23, 0, 0)),
#    ('2047',
#     '762 ',
#     'JIMENA   ',
#     Decimal('17.30'),
#     Decimal('-139.8000'),
#     85,
#     973,
#     'H2',
#     'Eastern Pacific',
#     Decimal('1.5000000'),
#     datetime.datetime(2003, 8, 30, 0, 0)),
#    ('2048',
#     '282 ',
#     'IONE     ',
#     Decimal('12.40'),
#     Decimal('-137.6000'),
#     30,
#     0,
#     'TD',
#     'Eastern Pacific',
#     Decimal('0.8062260'),
#     datetime.datetime(1974, 8, 23, 0, 0)),
#    ('2049',
#     '775 ',
#     'GEORGETTE',
#     Decimal('21.70'),
#     Decimal('-140.2000'),
#     15,
#     1011,
#     'L ',
#     'Eastern Pacific',
#     Decimal('1.6155490'),
#     datetime.datetime(2004, 9, 2, 0, 0)),
#    ('2050',
#     '282 ',
#     'IONE     ',
#     Decimal('12.50'),
#     Decimal('-138.4000'),
#     65,
#     0,
#     'H1',
#     'Eastern Pacific',
#     Decimal('0.9219540'),
#     datetime.datetime(1974, 8, 23, 0, 0)),
#    ('2051',
#     '797 ',
#     'BUD      ',
#     Decimal('23.00'),
#     Decimal('-139.8000'),
#     20,
#     1012,
#     'L ',
#     'Eastern Pacific',
#     Decimal('1.5811390'),
#     datetime.datetime(2006, 7, 16, 0, 0)),
#    ('2052',
#     '282 ',
#     'IONE     ',
#     Decimal('12.70'),
#     Decimal('-139.3000'),
#     75,
#     0,
#     'H1',
#     'Eastern Pacific',
#     Decimal('0.8246210'),
#     datetime.datetime(1974, 8, 24, 0, 0)),
#    ('2053',
#     '830 ',
#     'ELIDA    ',
#     Decimal('16.90'),
#     Decimal('-140.0000'),
#     25,
#     1009,
#     'L ',
#     'Eastern Pacific',
#     Decimal('1.5132750'),
#     datetime.datetime(2008, 7, 21, 0, 0)),
#    ('2054',
#     '282 ',
#     'IONE     ',
#     Decimal('12.90'),
#     Decimal('-140.1000'),
#     100,
#     0,
#     'H3',
#     'Eastern Pacific',
#     Decimal('0.9486830'),
#     datetime.datetime(1974, 8, 24, 0, 0)),
#    ('2055',
#     '12  ',
#     'NOTNAMED ',
#     Decimal('19.10'),
#     Decimal('-140.3000'),
#     75,
#     0,
#     'H1',
#     'Eastern Pacific',
#     Decimal('0.8246210'),
#     datetime.datetime(1950, 8, 29, 0, 0)),
#    ('2056',
#     '282 ',
#     'IONE     ',
#     Decimal('13.20'),
#     Decimal('-141.0000'),
#     90,
#     0,
#     'H2',
#     'Eastern Pacific',
#     Decimal('0.6324560'),
#     datetime.datetime(1974, 8, 24, 0, 0)),
#    ('2057',
#     '12  ',
#     'NOTNAMED ',
#     Decimal('19.30'),
#     Decimal('-141.1000'),
#     75,
#     0,
#     'H1',
#     'Eastern Pacific',
#     Decimal('0.9219540'),
#     datetime.datetime(1950, 8, 30, 0, 0)),
#    ('2058',
#     '282 ',
#     'IONE     ',
#     Decimal('13.40'),
#     Decimal('-141.6000'),
#     90,
#     0,
#     'H2',
#     'Eastern Pacific',
#     Decimal('0.5000000'),
#     datetime.datetime(1974, 8, 24, 0, 0)),
#    ('2059',
#     '12  ',
#     'NOTNAMED ',
#     Decimal('19.50'),
#     Decimal('-142.0000'),
#     75,
#     0,
#     'H1',
#     'Eastern Pacific',
#     Decimal('1.0198040'),
#     datetime.datetime(1950, 8, 30, 0, 0)),
#    ('2060',
#     '282 ',
#     'IONE     ',
#     Decimal('13.70'),
#     Decimal('-142.0000'),
#     90,
#     0,
#     'H2',
#     'Eastern Pacific',
#     Decimal('0.5000000'),
#     datetime.datetime(1974, 8, 25, 0, 0)),
#    ('2061',
#     '62  ',
#     'KANOA    ',
#     Decimal('17.90'),
#     Decimal('-140.5000'),
#     75,
#     0,
#     'H1',
#     'Eastern Pacific',
#     Decimal('1.3038400'),
#     datetime.datetime(1957, 7, 23, 0, 0)),
#    ('2062',
#     '62  ',
#     'KANOA    ',
#     Decimal('18.00'),
#     Decimal('-141.8000'),
#     75,
#     0,
#     'H1',
#     'Eastern Pacific',
#     Decimal('1.1401750'),
#     datetime.datetime(1957, 7, 23, 0, 0)),
#    ('2063',
#     '282 ',
#     'IONE     ',
#     Decimal('14.00'),
#     Decimal('-142.4000'),
#     90,
#     0,
#     'H2',
#     'Eastern Pacific',
#     Decimal('0.5830950'),
#     datetime.datetime(1974, 8, 25, 0, 0)),
#    ('2064',
#     '282 ',
#     'IONE     ',
#     Decimal('14.30'),
#     Decimal('-142.9000'),
#     90,
#     0,
#     'H2',
#     'Eastern Pacific',
#     Decimal('0.5656850'),
#     datetime.datetime(1974, 8, 25, 0, 0)),
#    ('2065',
#     '62  ',
#     'KANOA    ',
#     Decimal('18.30'),
#     Decimal('-142.9000'),
#     75,
#     0,
#     'H1',
#     'Eastern Pacific',
#     Decimal('1.1401750'),
#     datetime.datetime(1957, 7, 23, 0, 0)),
#    ('2066',
#     '66  ',
#     'NOTNAMED ',
#     Decimal('15.80'),
#     Decimal('-140.5000'),
#     45,
#     0,
#     'TS',
#     'Eastern Pacific',
#     Decimal('1.1180340'),
#     datetime.datetime(1957, 9, 9, 0, 0)),
#    ('2067',
#     '291 ',
#     'ROSALIE  ',
#     Decimal('13.50'),
#     Decimal('-136.0000'),
#     35,
#     0,
#     'TS',
#     'Eastern Pacific',
#     Decimal('0.5830950'),
#     datetime.datetime(1974, 10, 23, 0, 0)),
#    ('2068',
#     '66  ',
#     'NOTNAMED ',
#     Decimal('16.30'),
#     Decimal('-141.5000'),
#     45,
#     0,
#     'TS',
#     'Eastern Pacific',
#     Decimal('0.9848860'),
#     datetime.datetime(1957, 9, 9, 0, 0)),
#    ('2069',
#     '291 ',
#     'ROSALIE  ',
#     Decimal('13.20'),
#     Decimal('-136.5000'),
#     35,
#     0,
#     'TS',
#     'Eastern Pacific',
#     Decimal('0.5385160'),
#     datetime.datetime(1974, 10, 23, 0, 0)),
#    ('2070',
#     '291 ',
#     'ROSALIE  ',
#     Decimal('13.00'),
#     Decimal('-137.0000'),
#     35,
#     0,
#     'TS',
#     'Eastern Pacific',
#     Decimal('1.0049880'),
#     datetime.datetime(1974, 10, 23, 0, 0)),
#    ('2071',
#     '66  ',
#     'NOTNAMED ',
#     Decimal('16.70'),
#     Decimal('-142.4000'),
#     45,
#     0,
#     'TS',
#     'Eastern Pacific',
#     Decimal('0.6708200'),
#     datetime.datetime(1957, 9, 10, 0, 0)),
#    ('2072',
#     '291 ',
#     'ROSALIE  ',
#     Decimal('12.90'),
#     Decimal('-138.0000'),
#     25,
#     0,
#     'TD',
#     'Eastern Pacific',
#     Decimal('1.0049880'),
#     datetime.datetime(1974, 10, 23, 0, 0)),
#    ('2073',
#     '66  ',
#     'NOTNAMED ',
#     Decimal('17.00'),
#     Decimal('-143.0000'),
#     45,
#     0,
#     'TS',
#     'Eastern Pacific',
#     Decimal('0.5830950'),
#     datetime.datetime(1957, 9, 10, 0, 0)),
#    ('2074',
#     '311 ',
#     'CELESTE  ',
#     Decimal('12.50'),
#     Decimal('-135.7000'),
#     25,
#     0,
#     'TD',
#     'Eastern Pacific',
#     Decimal('2.2561030'),
#     datetime.datetime(1976, 7, 18, 0, 0)),
#    ('2075',
#     '93  ',
#     'DOT      ',
#     Decimal('15.70'),
#     Decimal('-141.2000'),
#     60,
#     0,
#     'TS',
#     'Eastern Pacific',
#     Decimal('0.6082760'),
#     datetime.datetime(1959, 8, 1, 0, 0)),
#    ('2076',
#     '93  ',
#     'DOT      ',
#     Decimal('15.80'),
#     Decimal('-141.8000'),
#     90,
#     0,
#     'H2',
#     'Eastern Pacific',
#     Decimal('1.1045360'),
#     datetime.datetime(1959, 8, 2, 0, 0)),
#    ('2077',
#     '311 ',
#     'CELESTE  ',
#     Decimal('13.00'),
#     Decimal('-137.9000'),
#     25,
#     0,
#     'TD',
#     'Eastern Pacific',
#     Decimal('1.2369320'),
#     datetime.datetime(1976, 7, 19, 0, 0)),
#    ('2078',
#     '93  ',
#     'DOT      ',
#     Decimal('15.70'),
#     Decimal('-142.9000'),
#     100,
#     0,
#     'H3',
#     'Eastern Pacific',
#     Decimal('1.1045360'),
#     datetime.datetime(1959, 8, 2, 0, 0)),
#    ('2079',
#     '311 ',
#     'CELESTE  ',
#     Decimal('13.30'),
#     Decimal('-139.1000'),
#     25,
#     0,
#     'TD',
#     'Eastern Pacific',
#     Decimal('0.4472140'),
#     datetime.datetime(1976, 7, 19, 0, 0)),
#    ('2080',
#     '124 ',
#     'C        ',
#     Decimal('17.90'),
#     Decimal('-142.1000'),
#     45,
#     0,
#     'TS',
#     'Eastern Pacific',
#     Decimal('0.8062260'),
#     datetime.datetime(1962, 8, 29, 0, 0)),
#    ('2081',
#     '314 ',
#     'FERNANDA ',
#     Decimal('12.10'),
#     Decimal('-136.3000'),
#     35,
#     0,
#     'TS',
#     'Eastern Pacific',
#     Decimal('0.7000000'),
#     datetime.datetime(1976, 7, 29, 0, 0)),
#    ('2082',
#     '124 ',
#     'C        ',
#     Decimal('17.80'),
#     Decimal('-142.9000'),
#     45,
#     0,
#     'TS',
#     'Eastern Pacific',
#     Decimal('1.1045360'),
#     datetime.datetime(1962, 8, 29, 0, 0)),
#    ('2083',
#     '314 ',
#     'FERNANDA ',
#     Decimal('12.10'),
#     Decimal('-137.0000'),
#     35,
#     0,
#     'TS',
#     'Eastern Pacific',
#     Decimal('0.6324560'),
#     datetime.datetime(1976, 7, 29, 0, 0)),
#    ('2084',
#     '314 ',
#     'FERNANDA ',
#     Decimal('12.30'),
#     Decimal('-137.6000'),
#     30,
#     0,
#     'TD',
#     'Eastern Pacific',
#     Decimal('0.6324560'),
#     datetime.datetime(1976, 7, 29, 0, 0)),
#    ('2085',
#     '154 ',
#     'CONNIE   ',
#     Decimal('17.60'),
#     Decimal('-140.8000'),
#     45,
#     0,
#     'TS',
#     'Eastern Pacific',
#     Decimal('0.9055390'),
#     datetime.datetime(1966, 8, 12, 0, 0)),
#    ('2086',
#     '314 ',
#     'FERNANDA ',
#     Decimal('12.50'),
#     Decimal('-138.2000'),
#     30,
#     0,
#     'TD',
#     'Eastern Pacific',
#     Decimal('0.9486830'),
#     datetime.datetime(1976, 7, 30, 0, 0)),
#    ('2087',
#     '154 ',
#     'CONNIE   ',
#     Decimal('17.70'),
#     Decimal('-141.7000'),
#     45,
#     0,
#     'TS',
#     'Eastern Pacific',
#     Decimal('0.9055390'),
#     datetime.datetime(1966, 8, 12, 0, 0)),
#    ('2088',
#     '154 ',
#     'CONNIE   ',
#     Decimal('17.80'),
#     Decimal('-142.6000'),
#     45,
#     0,
#     'TS',
#     'Eastern Pacific',
#     Decimal('0.7000000'),
#     datetime.datetime(1966, 8, 13, 0, 0)),
#    ('2089',
#     '314 ',
#     'FERNANDA ',
#     Decimal('12.80'),
#     Decimal('-139.1000'),
#     30,
#     0,
#     'TD',
#     'Eastern Pacific',
#     Decimal('0.9486830'),
#     datetime.datetime(1976, 7, 30, 0, 0)),
#    ('2090',
#     '168 ',
#     'DENISE   ',
#     Decimal('16.30'),
#     Decimal('-141.6000'),
#     45,
#     0,
#     'TS',
#     'Eastern Pacific',
#     Decimal('2.4083190'),
#     datetime.datetime(1967, 7, 14, 0, 0)),
#    ('2091',
#     '181 ',
#     'RAMONA   ',
#     Decimal('15.80'),
#     Decimal('-140.5000'),
#     25,
#     0,
#     'TD',
#     'Eastern Pacific',
#     Decimal('0.6082760'),
#     datetime.datetime(1967, 10, 29, 0, 0)),
#    ('2092',
#     '314 ',
#     'FERNANDA ',
#     Decimal('13.10'),
#     Decimal('-140.0000'),
#     30,
#     0,
#     'TD',
#     'Eastern Pacific',
#     Decimal('1.2041590'),
#     datetime.datetime(1976, 7, 30, 0, 0)),
#    ('2093',
#     '314 ',
#     'FERNANDA ',
#     Decimal('13.20'),
#     Decimal('-141.2000'),
#     30,
#     0,
#     'TD',
#     'Eastern Pacific',
#     Decimal('1.4035670'),
#     datetime.datetime(1976, 7, 30, 0, 0)),
#    ('2094',
#     '181 ',
#     'RAMONA   ',
#     Decimal('15.90'),
#     Decimal('-141.1000'),
#     25,
#     0,
#     'TD',
#     'Eastern Pacific',
#     Decimal('0.8000000'),
#     datetime.datetime(1967, 10, 29, 0, 0)),
#    ('2095',
#     '181 ',
#     'RAMONA   ',
#     Decimal('15.90'),
#     Decimal('-141.9000'),
#     45,
#     0,
#     'TS',
#     'Eastern Pacific',
#     Decimal('0.7071070'),
#     datetime.datetime(1967, 10, 29, 0, 0)),
#    ('2096',
#     '314 ',
#     'FERNANDA ',
#     Decimal('13.30'),
#     Decimal('-142.6000'),
#     30,
#     0,
#     'TD',
#     'Eastern Pacific',
#     Decimal('1.5033300'),
#     datetime.datetime(1976, 7, 31, 0, 0)),
#    ('2097',
#     '181 ',
#     'RAMONA   ',
#     Decimal('16.00'),
#     Decimal('-142.6000'),
#     45,
#     0,
#     'TS',
#     'Eastern Pacific',
#     Decimal('0.4123110'),
#     datetime.datetime(1967, 10, 30, 0, 0)),
#    ('2098',
#     '320 ',
#     'KATE     ',
#     Decimal('13.40'),
#     Decimal('-141.1000'),
#     30,
#     0,
#     'TD',
#     'Eastern Pacific',
#     Decimal('0.2828430'),
#     datetime.datetime(1976, 9, 22, 0, 0)),
#    ('2099',
#     '181 ',
#     'RAMONA   ',
#     Decimal('16.10'),
#     Decimal('-143.0000'),
#     45,
#     0,
#     'TS',
#     'Eastern Pacific',
#     Decimal('0.3162280'),
#     datetime.datetime(1967, 10, 30, 0, 0)),
#    ('2100',
#     '320 ',
#     'KATE     ',
#     Decimal('13.60'),
#     Decimal('-141.3000'),
#     30,
#     0,
#     'TD',
#     'Eastern Pacific',
#     Decimal('0.3162280'),
#     datetime.datetime(1976, 9, 22, 0, 0))],
#   'total': (118456,)}}
