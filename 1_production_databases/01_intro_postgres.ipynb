# %% [markdown]
# ### These are exercises done as part of <a href = "www.dataquest.io"> DataQuest</a>'s Data Engineer Path
# This is not replicated for commercial use; strictly personal development.<br>
# All exercises are (c) DataQuest, with slight modifications so they use my PostGres server on my localhost

# %% [markdown]
# #### Postgres Mission
# <b>1.  </b>Instructions:
# - Import the psycopg2 library.
# - Connect to the database with the user vbuser.
# - Use the print function to display the Connection object.
# - Close the Connection using the close method.

# %% [markdown]
# <font color = 'blue'>I used the following source to make the mission's code work on my local machine. I first created a database, created a user that can read-only</font><br> https://www.codementor.io/engineerapart/getting-started-with-postgresql-on-mac-osx-are8jcopb

# %%
import psycopg2
conn = psycopg2.connect("dbname=valenbisi2018 user=vbuser password=vbisi2018")
print(conn)
conn.close()
# Out:
# <connection object at 0x1060b0d18; dsn: 'user=vbuser dbname=valenbisi2018 password=xxx', closed: 0>

# %% [markdown]
# <b>2. </b>Instructions:
# - Connect to the valenbisi2018 database as the user vbuser
# - Using the Cursor object, create a string query that selects all from the vbstatic table.
# - Execute the query using the execute method.
# - Fetch all the results from the table and assign it to the variable notes.
# - Close the Connection using the close method.

# %% [markdown]
# <font color = 'blue'>I had to alter permissions here, so I used the following source. <br>Later, because I will be asked to commit changes to tables, a permission I do not wish to grant to `vbuser`, I will go back to using user `nmolivo`, which is a poweruser.</font><br>https://dba.stackexchange.com/questions/33943/granting-access-to-all-tables-for-a-user

# %%
import psycopg2
conn = psycopg2.connect("dbname=valenbisi2018 user=vbuser password=vbisi2018")
cur = conn.cursor()
cur.execute('SELECT * FROM vbstatic')
one = cur.fetchone()
total = cur.fetchall()
notes = total
conn.close()

# %%
notes
# Out:
# [(1,
#   '20/02/2018 05:27:07',
#   3,
#   17,
#   '007_PZA_DEL_MERCADO_TAULA_DE_CANVIS',
#   Decimal('-0.379183758'),
#   Decimal('39.47487228'),
#   20),
#  (2,
#   '20/02/2018 05:27:07',
#   14,
#   0,
#   '168_AVDA. MALVARROSA',
#   Decimal('-0.327885481'),
#   Decimal('39.47687127'),
#   15),
#  (3,
#   '20/02/2018 05:27:07',
#   0,
#   16,
#   '229_CALLE_AITANA_ESQ_AVDA_BURJASSOT',
#   Decimal('-0.394804819'),
#   Decimal('39.49310435'),
#   16),
#  (4,
#   '20/02/2018 05:27:07',
#   2,
#   18,
#   '248_AVDA_TRES_CRUCES_JOSE_MARIA_MORTES_LERMA',
#   Decimal('-0.404967901'),
#   Decimal('39.46284026'),
#   20),
#  (5,
#   '20/02/2018 05:27:07',
#   5,
#   11,
#   '220_CALLE_CASTAN_TOBEÑAS_ESQ_CALLE_DE_GOYA',
#   Decimal('-0.398319856'),
#   Decimal('39.47385529'),
#   16),
#  (6,
#   '20/02/2018 05:27:07',
#   6,
#   19,
#   '001_GUILLEN_DE_CASTRO',
#   Decimal('-0.382927645'),
#   Decimal('39.48004218'),
#   25),
#  (7,
#   '20/02/2018 05:27:07',
#   9,
#   6,
#   '026_CALLE_SAN_JOSE_DE_CALASANZ',
#   Decimal('-0.386050791'),
#   Decimal('39.46619525'),
#   15),
#  (8,
#   '20/02/2018 05:27:07',
#   7,
#   12,
#   '027_CALLE_SAN_VICENTE_MARTIR_129',
#   Decimal('-0.381849779'),
#   Decimal('39.46336224'),
#   20),
#  (9,
#   '20/02/2018 05:27:07',
#   0,
#   20,
#   '031_CALLE SALAMANCA',
#   Decimal('-0.36502668'),
#   Decimal('39.46736525'),
#   20),
#  (10,
#   '20/02/2018 05:27:07',
#   2,
#   15,
#   '34_AVDA. ANTIGUO REINO DE VALENCIA',
#   Decimal('-0.369959711'),
#   Decimal('39.46412224'),
#   17),
#  (11,
#   '20/02/2018 05:27:07',
#   2,
#   23,
#   '036_PZA_LOS_FUEROS_CONDE_TRENOR',
#   Decimal('-0.375434726'),
#   Decimal('39.4790723'),
#   25),
#  (12,
#   '20/02/2018 05:27:07',
#   12,
#   8,
#   '38_AVDA. PERIS Y VALERO',
#   Decimal('-0.370247717'),
#   Decimal('39.459402'),
#   20),
#  (13,
#   '20/02/2018 05:27:07',
#   17,
#   6,
#   '179_AVENIDA_DE_LA_PLATA_45',
#   Decimal('-0.366424704'),
#   Decimal('39.45547221'),
#   23),
#  (14,
#   '20/02/2018 05:27:07',
#   14,
#   6,
#   '42_AVDA. DE LA PLATA',
#   Decimal('-0.358656653'),
#   Decimal('39.45878122'),
#   20),
#  (15,
#   '20/02/2018 05:27:07',
#   12,
#   7,
#   '44_AVDA. GRAL. URRUTIA',
#   Decimal('-0.363012682'),
#   Decimal('39.45642921'),
#   19),
#  (16,
#   '20/02/2018 05:27:07',
#   18,
#   2,
#   '127_C/ DUQUE DE MANDAS',
#   Decimal('-0.364444669'),
#   Decimal('39.49059132'),
#   20),
#  (17,
#   '20/02/2018 05:27:07',
#   17,
#   8,
#   '128_C/ ALFAUIR',
#   Decimal('-0.367542686'),
#   Decimal('39.48876633'),
#   25),
#  (18,
#   '20/02/2018 05:27:07',
#   16,
#   4,
#   '129_C_ALMAZORA',
#   Decimal('-0.369943701'),
#   Decimal('39.48597531'),
#   20),
#  (19,
#   '20/02/2018 05:27:07',
#   11,
#   4,
#   '130_C/ CONVENTO CARMELITAS',
#   Decimal('-0.370208697'),
#   Decimal('39.4832383'),
#   15),
#  (20,
#   '20/02/2018 05:27:07',
#   1,
#   19,
#   '131_C/ ALBORAYA',
#   Decimal('-0.371161706'),
#   Decimal('39.48065329'),
#   20),
#  (21,
#   '20/02/2018 05:27:07',
#   15,
#   0,
#   '132_C/ RUAYA',
#   Decimal('-0.373432719'),
#   Decimal('39.48528632'),
#   15),
#  (22,
#   '20/02/2018 05:27:07',
#   12,
#   3,
#   '133_C/ ALFAMBRA',
#   Decimal('-0.375880731'),
#   Decimal('39.48275631'),
#   15),
#  (23,
#   '20/02/2018 05:27:07',
#   8,
#   7,
#   '139_C/ REUS',
#   Decimal('-0.382871767'),
#   Decimal('39.48570632'),
#   15),
#  (24,
#   '20/02/2018 05:27:07',
#   11,
#   9,
#   '180_AVENIDA_DOCTOR_WAKSMAN',
#   Decimal('-0.370681716'),
#   Decimal('39.45602122'),
#   20),
#  (25,
#   '20/02/2018 05:27:07',
#   0,
#   30,
#   '189_HOSPITAL_NUEVA_FE',
#   Decimal('-0.375900761'),
#   Decimal('39.44467118'),
#   30),
#  (26,
#   '20/02/2018 05:27:07',
#   7,
#   11,
#   '190_CTRA_MALILLA',
#   Decimal('-0.380294778'),
#   Decimal('39.44608219'),
#   18),
#  (27,
#   '20/02/2018 05:27:07',
#   7,
#   8,
#   '191_CTRA_MALILLA',
#   Decimal('-0.378864768'),
#   Decimal('39.4503292'),
#   15),
#  (28,
#   '20/02/2018 05:27:07',
#   2,
#   18,
#   '014_BARÓN CARCER',
#   Decimal('-0.379722766'),
#   Decimal('39.46896726'),
#   20),
#  (29,
#   '20/02/2018 05:27:07',
#   15,
#   0,
#   '072_RAMIRO MAETZU',
#   Decimal('-0.346306584'),
#   Decimal('39.46724424'),
#   15),
#  (30,
#   '20/02/2018 05:27:07',
#   20,
#   0,
#   '073_JERONIMO MONSORIU',
#   Decimal('-0.342877568'),
#   Decimal('39.46625924'),
#   20),
#  (31,
#   '20/02/2018 05:27:07',
#   18,
#   2,
#   '074_PLAZA SAN FELIPE NERI',
#   Decimal('-0.353732624'),
#   Decimal('39.46994926'),
#   20),
#  (32,
#   '20/02/2018 05:27:07',
#   20,
#   5,
#   '075_CAMPOAMOR I',
#   Decimal('-0.351699605'),
#   Decimal('39.47211326'),
#   25),
#  (33,
#   '20/02/2018 05:27:07',
#   19,
#   0,
#   '076_CAMPOAMOR II',
#   Decimal('-0.343459561'),
#   Decimal('39.47008324'),
#   19),
#  (34,
#   '20/02/2018 05:27:07',
#   19,
#   0,
#   '77_C/ MOLINELL',
#   Decimal('-0.365665673'),
#   Decimal('39.48497331'),
#   20),
#  (35,
#   '20/02/2018 05:27:07',
#   6,
#   9,
#   '181_CALLE_DEL_SALINAR',
#   Decimal('-0.36818971'),
#   Decimal('39.45799922'),
#   15),
#  (36,
#   '20/02/2018 05:27:07',
#   6,
#   14,
#   '078_AVDA. ARAGÓN I',
#   Decimal('-0.358686642'),
#   Decimal('39.46994526'),
#   20),
#  (37,
#   '20/02/2018 05:27:07',
#   0,
#   20,
#   '079_AVDA. ARAGON II',
#   Decimal('-0.357240642'),
#   Decimal('39.47277926'),
#   20),
#  (38,
#   '20/02/2018 05:27:07',
#   2,
#   23,
#   '080_AMADEO SAVOIA',
#   Decimal('-0.362296669'),
#   Decimal('39.47374227'),
#   25),
#  (39,
#   '20/02/2018 05:27:07',
#   1,
#   19,
#   '081_DOCTOR FORNOS',
#   Decimal('-0.360976656'),
#   Decimal('39.47512828'),
#   20),
#  (40,
#   '20/02/2018 05:27:07',
#   22,
#   3,
#   '150_DR. MANUEL CANDELA',
#   Decimal('-0.35060761'),
#   Decimal('39.46772125'),
#   25),
#  (41,
#   '20/02/2018 05:27:07',
#   20,
#   0,
#   '151_JERONIMO MONSORIU',
#   Decimal('-0.33711553'),
#   Decimal('39.46466923'),
#   20),
#  (42,
#   '20/02/2018 05:27:07',
#   10,
#   5,
#   '152_C/ LITERATO AZORÍN',
#   Decimal('-0.372703728'),
#   Decimal('39.46092523'),
#   15),
#  (43,
#   '20/02/2018 05:27:07',
#   4,
#   20,
#   '153_C/ LLANO DE ZAIDA',
#   Decimal('-0.380170751'),
#   Decimal('39.48316231'),
#   24),
#  (44,
#   '20/02/2018 05:27:07',
#   14,
#   0,
#   '154_PESCADORES',
#   Decimal('-0.329552492'),
#   Decimal('39.46987624'),
#   15),
#  (45,
#   '20/02/2018 05:27:07',
#   12,
#   8,
#   '155_C/ SALAMANCA',
#   Decimal('-0.363076673'),
#   Decimal('39.46495324'),
#   20),
#  (46,
#   '20/02/2018 05:27:07',
#   11,
#   10,
#   '182_AVDA_AUSIAS_MARCH',
#   Decimal('-0.374963743'),
#   Decimal('39.45543222'),
#   21),
#  (47,
#   '20/02/2018 05:27:07',
#   14,
#   0,
#   '199_CALLE_BEATO_NICOLAS_FACTOR',
#   Decimal('-0.391556832'),
#   Decimal('39.46158824'),
#   15),
#  (48,
#   '20/02/2018 05:27:07',
#   3,
#   12,
#   '200_AVDA_DEL_CID',
#   Decimal('-0.393212835'),
#   Decimal('39.46773727'),
#   15),
#  (49,
#   '20/02/2018 05:27:07',
#   16,
#   4,
#   '201_AVDA_PEREZ_GALDOS',
#   Decimal('-0.393666836'),
#   Decimal('39.47171228'),
#   20),
#  (50,
#   '20/02/2018 05:27:07',
#   17,
#   0,
#   '164_PAVIA 1',
#   Decimal('-0.324632463'),
#   Decimal('39.46846023'),
#   17),
#  (51,
#   '20/02/2018 05:27:07',
#   17,
#   3,
#   '165_PAVIA 2',
#   Decimal('-0.324568469'),
#   Decimal('39.47140924'),
#   20),
#  (52,
#   '20/02/2018 05:27:07',
#   13,
#   1,
#   '166_PROGRESO',
#   Decimal('-0.328809486'),
#   Decimal('39.47334925'),
#   15),
#  (53,
#   '20/02/2018 05:27:07',
#   3,
#   12,
#   '006_GUILLEN_CASTRO_CON_CALLE_SAN_PEDRO_PASCUAL',
#   Decimal('-0.384081776'),
#   Decimal('39.47279828'),
#   15),
#  (54,
#   '20/02/2018 05:27:07',
#   1,
#   21,
#   '008_PLAZA_DE_LA_REINA_ESQUINA_CALLE_DEL_MAR',
#   Decimal('-0.375082731'),
#   Decimal('39.47432028'),
#   23),
#  (55,
#   '20/02/2018 05:27:07',
#   1,
#   24,
#   '009_PLAZA_TETUAN_4',
#   Decimal('-0.369928706'),
#   Decimal('39.47435527'),
#   25),
#  (56,
#   '20/02/2018 05:27:07',
#   0,
#   15,
#   '010_CALLE_DEL_HOSPITAL_FRENTE_CALLE_HORNO_DEL_HOSP',
#   Decimal('-0.382608768'),
#   Decimal('39.47081627'),
#   15),
#  (57,
#   '20/02/2018 05:27:07',
#   10,
#   8,
#   '183_AVDA_AUSIAS_MARCH',
#   Decimal('-0.372282729'),
#   Decimal('39.45262021'),
#   18),
#  (58,
#   '20/02/2018 05:27:07',
#   2,
#   25,
#   '011_PZA_AYTO_CON_CALLE_COTANDA',
#   Decimal('-0.37678274'),
#   Decimal('39.47118627'),
#   27),
#  (59,
#   '20/02/2018 05:27:07',
#   1,
#   18,
#   '012_CALLE_MINYANA',
#   Decimal('-0.374008636'),
#   Decimal('39.47196717'),
#   20),
#  (60,
#   '20/02/2018 05:27:07',
#   1,
#   23,
#   '013_PZA. ALFONSO MAGNANIMO_CON_CALLE_LA_NAVE',
#   Decimal('-0.370872714'),
#   Decimal('39.47206227'),
#   24),
#  (61,
#   '20/02/2018 05:27:07',
#   2,
#   18,
#   '016_COLON I',
#   Decimal('-0.370431713'),
#   Decimal('39.47009226'),
#   20),
#  (62,
#   '20/02/2018 05:27:07',
#   2,
#   38,
#   '017_ESTACION RENFE I',
#   Decimal('-0.377257743'),
#   Decimal('39.46746826'),
#   40),
#  (63,
#   '20/02/2018 05:27:07',
#   1,
#   23,
#   '018_COLON II',
#   Decimal('-0.37312773'),
#   Decimal('39.46819126'),
#   24),
#  (64,
#   '20/02/2018 05:27:07',
#   11,
#   9,
#   '43_C/ DE ORIENTE',
#   Decimal('-0.361151664'),
#   Decimal('39.45947722'),
#   20),
#  (65,
#   '20/02/2018 05:27:07',
#   7,
#   8,
#   '082_GUILLEN_DE_CASTRO_TORRES_DE_QUART',
#   Decimal('-0.383912777'),
#   Decimal('39.47605629'),
#   15),
#  (66,
#   '20/02/2018 05:27:07',
#   11,
#   4,
#   '156_C/ CUBA',
#   Decimal('-0.37634375'),
#   Decimal('39.46096424'),
#   15),
#  (67,
#   '20/02/2018 05:27:07',
#   6,
#   14,
#   '157_AVENIDA_PEREZ_GALDOS',
#   Decimal('-0.387364808'),
#   Decimal('39.46405225'),
#   20),
#  (68,
#   '20/02/2018 05:27:07',
#   6,
#   8,
#   '184_CALLE_BOMBER_RAMON_DUART',
#   Decimal('-0.365568699'),
#   Decimal('39.45278221'),
#   15),
#  (69,
#   '20/02/2018 05:27:07',
#   15,
#   0,
#   '158_DR.LLUNCH',
#   Decimal('-0.327717488'),
#   Decimal('39.46669823'),
#   15),
#  (70,
#   '20/02/2018 05:27:07',
#   17,
#   0,
#   '159_FRANCISCO CUBELLS',
#   Decimal('-0.334720526'),
#   Decimal('39.46344922'),
#   17),
#  (71,
#   '20/02/2018 05:27:07',
#   20,
#   0,
#   '160_JOSE MARIA DE HARO',
#   Decimal('-0.338979542'),
#   Decimal('39.46733624'),
#   20),
#  (72,
#   '20/02/2018 05:27:07',
#   15,
#   0,
#   '161_MEDITERRANEO',
#   Decimal('-0.331724504'),
#   Decimal('39.46796924'),
#   15),
#  (73,
#   '20/02/2018 05:27:07',
#   18,
#   1,
#   '162_PZA. ARMADA ESPAÑOLA',
#   Decimal('-0.329793499'),
#   Decimal('39.46360422'),
#   19),
#  (74,
#   '20/02/2018 05:27:07',
#   17,
#   3,
#   '163_PASEO NEPTUNO',
#   Decimal('-0.323399465'),
#   Decimal('39.46443722'),
#   20),
#  (75,
#   '20/02/2018 05:27:07',
#   0,
#   25,
#   '028_NAVARRO REVERTE',
#   Decimal('-0.367749696'),
#   Decimal('39.47158227'),
#   25),
#  (76,
#   '20/02/2018 05:27:07',
#   1,
#   19,
#   '029_PLAZA AMERICA',
#   Decimal('-0.365297677'),
#   Decimal('39.47011226'),
#   20),
#  (77,
#   '20/02/2018 05:27:07',
#   1,
#   19,
#   '030_CIRILO AMOROS',
#   Decimal('-0.368497698'),
#   Decimal('39.46860126'),
#   20),
#  (78,
#   '20/02/2018 05:27:07',
#   9,
#   11,
#   '032_C/ CONDE DE ALTEA',
#   Decimal('-0.368245697'),
#   Decimal('39.46600625'),
#   20),
#  (79,
#   '20/02/2018 05:27:07',
#   7,
#   8,
#   '185_AVDA_AUSIAS_MARCH',
#   Decimal('-0.370501719'),
#   Decimal('39.4500442'),
#   15),
#  (80,
#   '20/02/2018 05:27:07',
#   4,
#   16,
#   '033_GRAN_VIA_GERMANIAS_ESQ_CALLE_RUZAFA',
#   Decimal('-0.373988738'),
#   Decimal('39.46481825'),
#   20),
#  (81,
#   '20/02/2018 05:27:07',
#   10,
#   5,
#   '45_AVDA. GRAL. URRUTIA',
#   Decimal('-0.361853674'),
#   Decimal('39.4538192'),
#   15),
#  (82,
#   '20/02/2018 05:27:07',
#   17,
#   3,
#   '46_AVDA. INSTITUTO OBRERO DE VALENCIA',
#   Decimal('-0.35878566'),
#   Decimal('39.45550921'),
#   20),
#  (83,
#   '20/02/2018 05:27:07',
#   0,
#   20,
#   '47_AVDA. AUTOPISTA DEL SALER',
#   Decimal('-0.355416639'),
#   Decimal('39.45651221'),
#   20),
#  (84,
#   '20/02/2018 05:27:07',
#   1,
#   19,
#   '48_AVDA. ANTONIO FERRANDIS',
#   Decimal('-0.358551054'),
#   Decimal('39.4508073'),
#   20),
#  (85,
#   '20/02/2018 05:27:07',
#   1,
#   24,
#   '49_C/ RICARDO MUÑOZ SUAY',
#   Decimal('-0.357108729'),
#   Decimal('39.45298688'),
#   25),
#  (86,
#   '20/02/2018 05:27:07',
#   22,
#   18,
#   '50_AVDA. AUTOPISTA DEL SALER',
#   Decimal('-0.35285763'),
#   Decimal('39.4533182'),
#   40),
#  (87,
#   '20/02/2018 05:27:07',
#   1,
#   19,
#   '51_PSO. DE LAS MORERAS',
#   Decimal('-0.347225603'),
#   Decimal('39.45218319'),
#   20),
#  (88,
#   '20/02/2018 05:27:07',
#   2,
#   18,
#   '058_PLAZA DE ESPAÑA',
#   Decimal('-0.381584767'),
#   Decimal('39.46621825'),
#   20),
#  (89,
#   '20/02/2018 05:27:07',
#   0,
#   30,
#   '89_AVDA. BLASCO IBAÑEZ',
#   Decimal('-0.35931664'),
#   Decimal('39.47780228'),
#   30),
#  (90,
#   '20/02/2018 05:27:07',
#   3,
#   11,
#   '186_CALLE_INGENIERO_JOAQUIN_BENLLOCH',
#   Decimal('-0.374013741'),
#   Decimal('39.4503912'),
#   14),
#  (91,
#   '20/02/2018 05:27:07',
#   0,
#   40,
#   '90_AVDA. BLASCO IBAÑEZ',
#   Decimal('-0.358965641'),
#   Decimal('39.47673428'),
#   40),
#  (92,
#   '20/02/2018 05:27:07',
#   4,
#   11,
#   '091_CALLE_GRABADOR_JORDAN_46_PLAZA_ESCULTOR_PASTOR',
#   Decimal('-0.367571708'),
#   Decimal('39.44412518'),
#   15),
#  (93,
#   '20/02/2018 05:27:07',
#   3,
#   17,
#   '092_AVDA. DE ARAGON, 4 - ESQ AVDA BLASCO IBAÑEZ',
#   Decimal('-0.355966629'),
#   Decimal('39.47586027'),
#   20),
#  (94,
#   '20/02/2018 05:27:07',
#   34,
#   4,
#   '93_AVADA_BLASCO_IBAÑEZ_DESP_C_POETA_DURAN_TORTAJAD',
#   Decimal('-0.343807568'),
#   Decimal('39.47228225'),
#   38),
#  (95,
#   '20/02/2018 05:27:07',
#   10,
#   9,
#   '094_AVDA. BLASCO IBAÑEZ 5',
#   Decimal('-0.351581605'),
#   Decimal('39.47537827'),
#   20),
#  (96,
#   '20/02/2018 05:27:07',
#   0,
#   36,
#   '95_AVDA. DE LOS NARANJOS',
#   Decimal('-0.346117577'),
#   Decimal('39.47983528'),
#   36),
#  (97,
#   '20/02/2018 05:27:07',
#   9,
#   12,
#   '096_AVDA. BLASCO IBAÑEZ 6',
#   Decimal('-0.348212588'),
#   Decimal('39.47355427'),
#   21),
#  (98,
#   '20/02/2018 05:27:07',
#   22,
#   1,
#   '097_AVDA. BLASCO IBAÑEZ 7',
#   Decimal('-0.343130557'),
#   Decimal('39.47306826'),
#   23),
#  (99,
#   '20/02/2018 05:27:07',
#   14,
#   1,
#   '098_SANTOS JUSTO Y PASTOR',
#   Decimal('-0.348440592'),
#   Decimal('39.46968025'),
#   15),
#  (100,
#   '20/02/2018 05:27:07',
#   16,
#   3,
#   '134_C/ MAXIMILIANO THOUS',
#   Decimal('-0.373337716'),
#   Decimal('39.48765632'),
#   20),
#  (101,
#   '20/02/2018 05:27:07',
#   1,
#   14,
#   '187_AVDA_AUSIAS_MARCH',
#   Decimal('-0.368816712'),
#   Decimal('39.44796019'),
#   15),
#  (102,
#   '20/02/2018 05:27:07',
#   20,
#   0,
#   '135_AVDA. CONSTITUCIÓN',
#   Decimal('-0.378499737'),
#   Decimal('39.48570232'),
#   20),
#  (103,
#   '20/02/2018 05:27:07',
#   12,
#   8,
#   '136_CALLE_ECONOMISTA_GAY',
#   Decimal('-0.375608722'),
#   Decimal('39.48994133'),
#   20),
#  (104,
#   '20/02/2018 05:27:07',
#   12,
#   8,
#   '137_CALLE_ECONOMISTA_GAY',
#   Decimal('-0.379894747'),
#   Decimal('39.48903333'),
#   20),
#  (105,
#   '20/02/2018 05:27:07',
#   5,
#   15,
#   '138_SAN_PANCRACIO',
#   Decimal('-0.384220766'),
#   Decimal('39.48819033'),
#   20),
#  (106,
#   '20/02/2018 05:27:07',
#   12,
#   8,
#   '140_AVENIDA_CAMPANAR',
#   Decimal('-0.389598803'),
#   Decimal('39.48800434'),
#   20),
#  (107,
#   '20/02/2018 05:27:07',
#   17,
#   3,
#   '141_C/ GREGORIO GEA (PEATONAL)',
#   Decimal('-0.385154784'),
#   Decimal('39.48326831'),
#   20),
#  (108,
#   '20/02/2018 05:27:07',
#   2,
#   23,
#   '142_C/ GREGORIO GEA (PEATONAL)',
#   Decimal('-0.389657798'),
#   Decimal('39.48192031'),
#   25),
#  (109,
#   '20/02/2018 05:27:07',
#   2,
#   28,
#   '143_AVDA. MENENDEZ PIDAL',
#   Decimal('-0.390934815'),
#   Decimal('39.4795373'),
#   30),
#  (110,
#   '20/02/2018 05:27:07',
#   1,
#   14,
#   '144_CALLE_MARQUES_DE_SAN_JUAN',
#   Decimal('-0.395478836'),
#   Decimal('39.4787793'),
#   15),
#  (111,
#   '20/02/2018 05:27:07',
#   0,
#   0,
#   '145_PLAZA_BADAJOZ',
#   Decimal('-0.398393845'),
#   Decimal('39.48154732'),
#   15),
#  (112,
#   '20/02/2018 05:27:07',
#   10,
#   6,
#   '021_JUAN_LLORENS_29',
#   Decimal('-0.390212816'),
#   Decimal('39.47237128'),
#   16),
#  (113,
#   '20/02/2018 05:27:07',
#   0,
#   40,
#   '188_HOSPITAL_NUEVA_FE',
#   Decimal('-0.373789745'),
#   Decimal('39.44449518'),
#   40),
#  (114,
#   '20/02/2018 05:27:07',
#   0,
#   26,
#   '146_AVDA. CAMPANAR',
#   Decimal('-0.390950813'),
#   Decimal('39.48511032'),
#   26),
#  (115,
#   '20/02/2018 05:27:07',
#   4,
#   11,
#   '147_CALLE_PIE_DE_LA_CRUZ_CALLE_DE_LA_REJA',
#   Decimal('-0.380205754'),
#   Decimal('39.47320128'),
#   15),
#  (116,
#   '20/02/2018 05:27:07',
#   20,
#   0,
#   '149_AVDA. PERIS Y VALERO',
#   Decimal('-0.361793668'),
#   Decimal('39.46293423'),
#   20),
#  (117,
#   '20/02/2018 05:27:07',
#   16,
#   2,
#   '169_PAVIA 4',
#   Decimal('-0.324643465'),
#   Decimal('39.47878526'),
#   20),
#  (118,
#   '20/02/2018 05:27:07',
#   18,
#   1,
#   '170_PAVIA 5',
#   Decimal('-0.325332461'),
#   Decimal('39.48297329'),
#   20),
#  (119,
#   '20/02/2018 05:27:07',
#   15,
#   0,
#   '171_CALLE GRAN CANARIA',
#   Decimal('-0.329006481'),
#   Decimal('39.48306028'),
#   15),
#  (120,
#   '20/02/2018 05:27:07',
#   0,
#   20,
#   '172_AVENIDA_PIO_XII',
#   Decimal('-0.39334382'),
#   Decimal('39.48146232'),
#   20),
#  (121,
#   '20/02/2018 05:27:07',
#   3,
#   17,
#   '173_AVENIDA_PIO_XII_34',
#   Decimal('-0.394676822'),
#   Decimal('39.48454132'),
#   20),
#  (122,
#   '20/02/2018 05:27:07',
#   7,
#   12,
#   '174_CALLE_MONDUBER',
#   Decimal('-0.386645778'),
#   Decimal('39.48943834'),
#   19),
#  (123,
#   '20/02/2018 05:27:07',
#   5,
#   10,
#   '175_CALLE_JUAN_XXIII',
#   Decimal('-0.382710754'),
#   Decimal('39.49258934'),
#   15),
#  (124,
#   '20/02/2018 05:27:07',
#   14,
#   1,
#   '196_AVDA_GASPAR_AGUILAR',
#   Decimal('-0.388064811'),
#   Decimal('39.45957523'),
#   15),
#  (125,
#   '20/02/2018 05:27:07',
#   15,
#   5,
#   '176_CAMINO_DE_MONCADA_52',
#   Decimal('-0.378851744'),
#   Decimal('39.49201734'),
#   20),
#  (126,
#   '20/02/2018 05:27:07',
#   14,
#   1,
#   '177_CALLE_ALCUDIA',
#   Decimal('-0.373486712'),
#   Decimal('39.49354534'),
#   15),
#  (127,
#   '20/02/2018 05:27:07',
#   16,
#   4,
#   '178_CALLE_REIG_GENOVES',
#   Decimal('-0.370504696'),
#   Decimal('39.49221634'),
#   20),
#  (128,
#   '20/02/2018 05:27:07',
#   7,
#   13,
#   '192_CTRA_MALILLA',
#   Decimal('-0.378712765'),
#   Decimal('39.45263721'),
#   20),
#  (129,
#   '20/02/2018 05:27:07',
#   17,
#   3,
#   '193_CALLE_CARTEROS',
#   Decimal('-0.386716801'),
#   Decimal('39.45514622'),
#   20),
#  (130,
#   '20/02/2018 05:27:07',
#   2,
#   38,
#   '194_ESTACION_AVE_JOAQUIN_SOROLLA',
#   Decimal('-0.380972776'),
#   Decimal('39.46101824'),
#   40),
#  (131,
#   '20/02/2018 05:27:07',
#   11,
#   5,
#   '195_CALLE_GIORGETA',
#   Decimal('-0.384279785'),
#   Decimal('39.45938424'),
#   16),
#  (132,
#   '20/02/2018 05:27:07',
#   6,
#   8,
#   '249_AVDA_TRES_CRUCES_SEGUNDA_REPUBLICA_ESPAÑOLA',
#   Decimal('-0.402738884'),
#   Decimal('39.45950624'),
#   15),
#  (133,
#   '20/02/2018 05:27:07',
#   9,
#   6,
#   '250_AVDA_TRES_CRUCES_PIO_XI',
#   Decimal('-0.400805409'),
#   Decimal('39.45635219'),
#   15),
#  (134,
#   '20/02/2018 05:27:07',
#   14,
#   1,
#   '251_ARQUITECTO_SEGURA_LAGO_CAMINO_NUEVO_DE_PICAÑA',
#   Decimal('-0.404411904'),
#   Decimal('39.45583023'),
#   15),
#  (135,
#   '20/02/2018 05:27:07',
#   11,
#   4,
#   '197_CALLE_FONTANARS_DELS_AFORINS',
#   Decimal('-0.392331834'),
#   Decimal('39.45818423'),
#   15),
#  (136,
#   '20/02/2018 05:27:07',
#   11,
#   4,
#   '256_AVDA_TRES_FORQUES_TURIS',
#   Decimal('-0.392233832'),
#   Decimal('39.46396325'),
#   15),
#  (137,
#   '20/02/2018 05:27:07',
#   0,
#   20,
#   '257_PLAZA_SALVADOR_SORIA_ESQ_PIO_X',
#   Decimal('-0.389102828'),
#   Decimal('39.44525119'),
#   20),
#  (138,
#   '20/02/2018 05:27:07',
#   14,
#   1,
#   '258_PINTOR_RAFAEL_SOLVES_ESQ_JOSE_SOTO_MICO',
#   Decimal('-0.389135824'),
#   Decimal('39.43982817'),
#   15),
#  (139,
#   '20/02/2018 05:27:07',
#   17,
#   2,
#   '259_CALLE_PIO_IX_POLIDEPORTIVO_RAMBLETA',
#   Decimal('-0.393013851'),
#   Decimal('39.44546019'),
#   20),
#  (140,
#   '20/02/2018 05:27:07',
#   0,
#   20,
#   '260_DELS_FERRERS_ESQ_TRAGINERS',
#   Decimal('-0.407215907'),
#   Decimal('39.45955624'),
#   20),
#  (141,
#   '20/02/2018 05:27:07',
#   18,
#   1,
#   '261_PZA_XUQUER_ESQ_VINALOPO',
#   Decimal('-0.350375598'),
#   Decimal('39.47667627'),
#   19),
#  (142,
#   '20/02/2018 05:27:07',
#   2,
#   18,
#   '262_AVDA_TRES_FORQUES_COLONIA_ESPANOLA_DE_MEXICO',
#   Decimal('-0.409223923'),
#   Decimal('39.46347226'),
#   20),
#  (143,
#   '20/02/2018 05:27:07',
#   14,
#   4,
#   '263_PADRE ESTEBAN_PERNET_ANTES_CASA_MISERICORDIA',
#   Decimal('-0.409642916'),
#   Decimal('39.46704327'),
#   18),
#  (144,
#   '20/02/2018 05:27:07',
#   6,
#   10,
#   '264_AVDA_CID_ANTES_MARCONI',
#   Decimal('-0.414430941'),
#   Decimal('39.46916028'),
#   20),
#  (145,
#   '20/02/2018 05:27:07',
#   2,
#   13,
#   '265_C_ALCASSER_POETA_ALBERTO_LISTA',
#   Decimal('-0.408115904'),
#   Decimal('39.47097329'),
#   15),
#  (146,
#   '20/02/2018 05:27:07',
#   3,
#   17,
#   '198_CALLE_FONTANARS_DELS_AFORINS',
#   Decimal('-0.395314843'),
#   Decimal('39.46088025'),
#   20),
#  (147,
#   '20/02/2018 05:27:07',
#   13,
#   5,
#   '266_PLANA_ALTA_ESQ_AVDA_MAESTRO_RODRIGO',
#   Decimal('-0.406369883'),
#   Decimal('39.49028935'),
#   18),
#  (148,
#   '20/02/2018 05:27:07',
#   6,
#   9,
#   '267_C_BENIFERRI_VICENTE_TOMAS_MARTI',
#   Decimal('-0.405927882'),
#   Decimal('39.49416836'),
#   16),
#  (149,
#   '20/02/2018 05:27:07',
#   7,
#   9,
#   '270_CALLE_NINOT_ESQ_PZA_REGINO_MAS',
#   Decimal('-0.392887812'),
#   Decimal('39.50007537'),
#   16),
#  (150,
#   '20/02/2018 05:27:07',
#   4,
#   11,
#   '271_CALLE_SALVADOR_CERVERÓ_CALLE_CARLOS_CORTINA',
#   Decimal('-0.389889787'),
#   Decimal('39.49927937'),
#   15),
#  (151,
#   '20/02/2018 05:27:07',
#   4,
#   11,
#   '273_CALLE_MORAIRA_CALLE_DALT_DE_LA_MAR',
#   Decimal('-0.333270519'),
#   Decimal('39.45030518'),
#   15),
#  (152,
#   '20/02/2018 05:27:07',
#   7,
#   8,
#   '274_MANUEL_ANDRES_CASTELL_DE_POLOP',
#   Decimal('-0.333186523'),
#   Decimal('39.44807017'),
#   15),
#  (153,
#   '20/02/2018 05:27:07',
#   20,
#   0,
#   '275_CAMINO_DE_LAS_MORERAS_ESQ_RONDA_DE_NAZARET',
#   Decimal('-0.335063538'),
#   Decimal('39.45230519'),
#   20),
#  (154,
#   '20/02/2018 05:27:07',
#   15,
#   5,
#   '276_EDIFICIO_VELES_E_VENTS',
#   Decimal('-0.323763469'),
#   Decimal('39.46197521'),
#   20),
#  (155,
#   '20/02/2018 05:27:07',
#   20,
#   0,
#   '252_DE_LOS_GREMIOS_CAMPOS_CRESPO',
#   Decimal('-0.403572893'),
#   Decimal('39.45028822'),
#   20),
#  (156,
#   '20/02/2018 05:27:07',
#   13,
#   2,
#   '253_PLAZA_JOSE_MELIA_CASTELLO_CAMPOS_CRESPO',
#   Decimal('-0.401099884'),
#   Decimal('39.45272622'),
#   15),
#  (157,
#   '20/02/2018 05:27:07',
#   18,
#   7,
#   '52_C/ LUIS GARCIA BERLANGA',
#   Decimal('-0.346338594'),
#   Decimal('39.4560342'),
#   25),
#  (158,
#   '20/02/2018 05:27:07',
#   8,
#   11,
#   '254_AVDA_DR_TOMAS_SALA_CARTEROS',
#   Decimal('-0.389915824'),
#   Decimal('39.4477142'),
#   19),
#  (159,
#   '20/02/2018 05:27:07',
#   3,
#   15,
#   '255_SAN_VICENTE_MARTIR_TOMAS_DE_VILLAROYA',
#   Decimal('-0.386027802'),
#   Decimal('39.4477032'),
#   18),
#  (160,
#   '20/02/2018 05:27:07',
#   14,
#   0,
#   '233_SAN_JUAN_BOSCO_SANTIAGO_RUSIÑOL',
#   Decimal('-0.369435682'),
#   Decimal('39.49716035'),
#   15),
#  (161,
#   '20/02/2018 05:27:07',
#   15,
#   0,
#   '234_PLAZA MUSICO_ESPI_JOSE_ESTEVE',
#   Decimal('-0.373642712'),
#   Decimal('39.49649935'),
#   15),
#  (162,
#   '20/02/2018 05:27:07',
#   11,
#   4,
#   '235_CONDE_DE_TORREFIEL_CECILIO_PLA',
#   Decimal('-0.377201722'),
#   Decimal('39.49804536'),
#   15),
#  (163,
#   '20/02/2018 05:27:07',
#   10,
#   4,
#   '236_RIO_SEGRE_RAFAEL_COMPANY',
#   Decimal('-0.382276757'),
#   Decimal('39.49506635'),
#   15),
#  (164,
#   '20/02/2018 05:27:07',
#   3,
#   12,
#   '237_LEVANTE_UD_AVDA_ECUADOR',
#   Decimal('-0.391036799'),
#   Decimal('39.49475835'),
#   15),
#  (165,
#   '20/02/2018 05:27:07',
#   6,
#   9,
#   '238_SAN_JOSE_ARTESANO_FRANCISCO_MOROTE_GREUS',
#   Decimal('-0.394381819'),
#   Decimal('39.49744937'),
#   15),
#  (166,
#   '20/02/2018 05:27:07',
#   1,
#   19,
#   '239_LA_FLORISTA_TRANVIA_PALACIO_CONGRESOS',
#   Decimal('-0.39996285'),
#   Decimal('39.49698537'),
#   20),
#  (167,
#   '20/02/2018 05:27:07',
#   20,
#   0,
#   '240_CAMP_DEL_TURIA_AVDA_CORTES_VALENCIANAS',
#   Decimal('-0.401545859'),
#   Decimal('39.49500436'),
#   20),
#  (168,
#   '20/02/2018 05:27:07',
#   19,
#   1,
#   '068_AVDA. DEL PUERTO IV',
#   Decimal('-0.341731567'),
#   Decimal('39.46280322'),
#   20),
#  (169,
#   '20/02/2018 05:27:07',
#   0,
#   15,
#   '241_VALL_DE_ALBAIDA_PEATONAL',
#   Decimal('-0.401888866'),
#   Decimal('39.49297835'),
#   15),
#  (170,
#   '20/02/2018 05:27:07',
#   2,
#   13,
#   '242_LA_SAFOR_AVDA_MAESTRO_RODRIGO',
#   Decimal('-0.404195874'),
#   Decimal('39.48790734'),
#   15),
#  (171,
#   '20/02/2018 05:27:07',
#   4,
#   11,
#   '269_CAMPAMENTO_81',
#   Decimal('-0.426261981'),
#   Decimal('39.49990739'),
#   15),
#  (172,
#   '20/02/2018 05:27:07',
#   0,
#   40,
#   '088_AVDA. BLASCO IBAÑEZ 3',
#   Decimal('-0.36114066'),
#   Decimal('39.47751228'),
#   40),
#  (173,
#   '20/02/2018 05:27:07',
#   21,
#   0,
#   '099_AVDA. BLASCO IBAÑEZ 8',
#   Decimal('-0.340482549'),
#   Decimal('39.47134425'),
#   21),
#  (174,
#   '20/02/2018 05:27:07',
#   20,
#   0,
#   '100_AVDA. BLASCO IBAÑEZ 9',
#   Decimal('-0.338148532'),
#   Decimal('39.47163425'),
#   20),
#  (175,
#   '20/02/2018 05:27:07',
#   30,
#   0,
#   '101_AVDA. BLASCO IBAÑEZ 10',
#   Decimal('-0.334359511'),
#   Decimal('39.47006824'),
#   30),
#  (176,
#   '20/02/2018 05:27:07',
#   10,
#   10,
#   '102_AVDA.RAMON LLUL',
#   Decimal('-0.346718585'),
#   Decimal('39.47583327'),
#   20),
#  (177,
#   '20/02/2018 05:27:07',
#   15,
#   0,
#   '103_RUBEN DARIO',
#   Decimal('-0.352369612'),
#   Decimal('39.47845328'),
#   15),
#  (178,
#   '20/02/2018 05:27:07',
#   4,
#   15,
#   '104_ALBALAT DELS TARONGERS',
#   Decimal('-0.34727358'),
#   Decimal('39.47838628'),
#   20),
#  (179,
#   '20/02/2018 05:27:07',
#   24,
#   1,
#   '069_AVDA. DEL PUERTO',
#   Decimal('-0.338719545'),
#   Decimal('39.46195222'),
#   25),
#  (180,
#   '20/02/2018 05:27:07',
#   1,
#   29,
#   '105_AVDA. DE LOS NARANJOS',
#   Decimal('-0.344518562'),
#   Decimal('39.47769027'),
#   30),
#  (181,
#   '20/02/2018 05:27:07',
#   11,
#   14,
#   '106_AVDA. DE LOS NARANJOS',
#   Decimal('-0.34138555'),
#   Decimal('39.47674427'),
#   25),
#  (182,
#   '20/02/2018 05:27:07',
#   15,
#   0,
#   '107_C/ CAMPILLO ALTO BUEY',
#   Decimal('-0.336222529'),
#   Decimal('39.47524526'),
#   15),
#  (183,
#   '20/02/2018 05:27:07',
#   15,
#   0,
#   '108_ LUIS PEIXO',
#   Decimal('-0.333610506'),
#   Decimal('39.47368626'),
#   15),
#  (184,
#   '20/02/2018 05:27:07',
#   13,
#   7,
#   '109_AVDA. NARANJOS',
#   Decimal('-0.333508505'),
#   Decimal('39.47681927'),
#   20),
#  (185,
#   '20/02/2018 05:27:07',
#   13,
#   17,
#   '110_KISSHOMARU',
#   Decimal('-0.336678527'),
#   Decimal('39.48074028'),
#   30),
#  (186,
#   '20/02/2018 05:27:07',
#   0,
#   30,
#   '111_COLEGIO MAYOR',
#   Decimal('-0.340559541'),
#   Decimal('39.48021628'),
#   30),
#  (187,
#   '20/02/2018 05:27:07',
#   3,
#   37,
#   '112_AVDA. DE LOS NARANJOS',
#   Decimal('-0.342273559'),
#   Decimal('39.47858027'),
#   40),
#  (188,
#   '20/02/2018 05:27:07',
#   0,
#   38,
#   '113_ETS CAMINOS',
#   Decimal('-0.343609559'),
#   Decimal('39.48127628'),
#   38),
#  (189,
#   '20/02/2018 05:27:07',
#   0,
#   30,
#   '114_ADOLFO SUAREZ',
#   Decimal('-0.346589571'),
#   Decimal('39.48180429'),
#   30),
#  (190,
#   '20/02/2018 05:27:07',
#   0,
#   17,
#   '70_CALLE_COLON_ESQ_ALMIRANTE_ROGER_DE_LAURIA',
#   Decimal('-0.371644634'),
#   Decimal('39.46921317'),
#   17),
#  (191,
#   '20/02/2018 05:27:07',
#   13,
#   3,
#   '115_C/ DR. VICENTE ZARAGOZA',
#   Decimal('-0.352146606'),
#   Decimal('39.48156229'),
#   16),
#  (192,
#   '20/02/2018 05:27:07',
#   15,
#   0,
#   '116_C/ DR. VICENTE ZARAGOZA',
#   Decimal('-0.357559632'),
#   Decimal('39.4832533'),
#   15),
#  (193,
#   '20/02/2018 05:27:07',
#   14,
#   1,
#   '272_VICENTE_LA_RODA_C_INGENIERO_FAUSTO_ELIO',
#   Decimal('-0.332188494'),
#   Decimal('39.48062327'),
#   15),
#  (194,
#   '20/02/2018 05:27:07',
#   20,
#   0,
#   '071_AVDA DEL PUERTO VI',
#   Decimal('-0.333529523'),
#   Decimal('39.46038021'),
#   20),
#  (195,
#   '20/02/2018 05:27:07',
#   0,
#   25,
#   '83_PZA. DE LA LEGIÓN ESPAÑOLA',
#   Decimal('-0.366968686'),
#   Decimal('39.47758529'),
#   25),
#  (196,
#   '20/02/2018 05:27:07',
#   13,
#   1,
#   '022_JUAN_LLORENS_57',
#   Decimal('-0.388351806'),
#   Decimal('39.46978727'),
#   15),
#  (197,
#   '20/02/2018 05:27:07',
#   0,
#   34,
#   '015_RIBERA',
#   Decimal('-0.37563574'),
#   Decimal('39.46908827'),
#   34),
#  (198,
#   '20/02/2018 05:27:07',
#   6,
#   9,
#   '019_JUAN_LLORENS',
#   Decimal('-0.39158882'),
#   Decimal('39.47436929'),
#   15),
#  (199,
#   '20/02/2018 05:27:07',
#   2,
#   17,
#   '023_GRAN_VIA_FERNANDO_EL_CATOLICO',
#   Decimal('-0.386176797'),
#   Decimal('39.47162828'),
#   19),
#  (200,
#   '20/02/2018 05:27:07',
#   13,
#   7,
#   '54_PASEO ALAMEDA',
#   Decimal('-0.352688616'),
#   Decimal('39.45977822'),
#   20),
#  (201,
#   '20/02/2018 05:27:07',
#   23,
#   2,
#   '55_AVDA. DE FRANCIA',
#   Decimal('-0.348684596'),
#   Decimal('39.45934322'),
#   25),
#  (202,
#   '20/02/2018 05:27:07',
#   9,
#   6,
#   '56_AVDA. DE FRANCIA',
#   Decimal('-0.344403576'),
#   Decimal('39.45842121'),
#   15),
#  (203,
#   '20/02/2018 05:27:07',
#   16,
#   4,
#   '057_CALLE PINTOR MONLEON',
#   Decimal('-0.358254653'),
#   Decimal('39.46447624'),
#   20),
#  (204,
#   '20/02/2018 05:27:07',
#   14,
#   1,
#   '059_AVDA. DE BALEARES I',
#   Decimal('-0.354547634'),
#   Decimal('39.46308823'),
#   15),
#  (205,
#   '20/02/2018 05:27:07',
#   10,
#   10,
#   '063_AVDA. DEL PUERTO I',
#   Decimal('-0.358412648'),
#   Decimal('39.46777925'),
#   20),
#  (206,
#   '20/02/2018 05:27:07',
#   20,
#   0,
#   '064_AVDA. DEL PUERTO II',
#   Decimal('-0.35419362'),
#   Decimal('39.46651824'),
#   20),
#  (207,
#   '20/02/2018 05:27:07',
#   6,
#   14,
#   '024_GRAN_VIA_RAMON_Y_CAJAL',
#   Decimal('-0.384025777'),
#   Decimal('39.46907726'),
#   20),
#  (208,
#   '20/02/2018 05:27:07',
#   19,
#   0,
#   '065_AVDA. DEL PUERTO III',
#   Decimal('-0.350835613'),
#   Decimal('39.46551623'),
#   19),
#  (209,
#   '20/02/2018 05:27:07',
#   25,
#   0,
#   '066_GUILLEN DE ANGLESOLA',
#   Decimal('-0.346259586'),
#   Decimal('39.46427123'),
#   25),
#  (210,
#   '20/02/2018 05:27:07',
#   13,
#   1,
#   '067_JUAN VERDEGUER',
#   Decimal('-0.336796541'),
#   Decimal('39.45886021'),
#   14),
#  (211,
#   '20/02/2018 05:27:07',
#   17,
#   1,
#   '120_C_DR VICENTE ZARAGOZA',
#   Decimal('-0.362044657'),
#   Decimal('39.48488031'),
#   18),
#  (212,
#   '20/02/2018 05:27:07',
#   15,
#   0,
#   '121_C_MURTA',
#   Decimal('-0.358769633'),
#   Decimal('39.48618231'),
#   15),
#  (213,
#   '20/02/2018 05:27:07',
#   20,
#   0,
#   '123_C_ALBOCACER',
#   Decimal('-0.364839665'),
#   Decimal('39.48767132'),
#   20),
#  (214,
#   '20/02/2018 05:27:07',
#   1,
#   19,
#   '202_PASEO_PECHINA',
#   Decimal('-0.393332826'),
#   Decimal('39.47622229'),
#   20),
#  (215,
#   '20/02/2018 05:27:07',
#   5,
#   10,
#   '203_CALLE_REINA_VIOLANTE',
#   Decimal('-0.401180861'),
#   Decimal('39.48460933'),
#   15),
#  (216,
#   '20/02/2018 05:27:07',
#   1,
#   19,
#   '204_AVDA_GENERAL_AVILES',
#   Decimal('-0.39658584'),
#   Decimal('39.48584333'),
#   20),
#  (217,
#   '20/02/2018 05:27:07',
#   8,
#   16,
#   '205_CALLE_NICASIO_BENLLOCH',
#   Decimal('-0.393088821'),
#   Decimal('39.48928733'),
#   24),
#  (218,
#   '20/02/2018 05:27:07',
#   10,
#   13,
#   '025_CALLE_DEL_ALBERIC',
#   Decimal('-0.388608811'),
#   Decimal('39.46772926'),
#   23),
#  (219,
#   '20/02/2018 05:27:07',
#   1,
#   14,
#   '206_CALLE_PERIODISTA_GIL_SUMBIELA',
#   Decimal('-0.389005788'),
#   Decimal('39.49271235'),
#   15),
#  (220,
#   '20/02/2018 05:27:07',
#   8,
#   7,
#   '207_CALLE_MILLARES_ESQ_CALLE_FEDERICO_GARCA_LORCA',
#   Decimal('-0.38190378'),
#   Decimal('39.45539322'),
#   15),
#  (221,
#   '20/02/2018 05:27:07',
#   0,
#   15,
#   '210_CALLE_CAMPOS_CRESPO_ESQ_CALLE_JUAN_DE_GARAY',
#   Decimal('-0.396714855'),
#   Decimal('39.45555323'),
#   15),
#  (222,
#   '20/02/2018 05:27:07',
#   2,
#   13,
#   "211_CALLE_FRAY_JUNÍPERO_SERRA_ESQ_CALLE_VALL_D'UIX",
#   Decimal('-0.397755857'),
#   Decimal('39.45872624'),
#   15),
#  (223,
#   '20/02/2018 05:27:07',
#   2,
#   13,
#   '212_CALLE_FRAY_JUANÍPERO_SERRA_ESQ_CALLE_TORRENTE',
#   Decimal('-0.400394872'),
#   Decimal('39.46148425'),
#   15),
#  (224,
#   '20/02/2018 05:27:07',
#   13,
#   2,
#   '213_CALLE_ARCHIDUQUE_CARLOS_ESQ_CALLE_JOSE_MA_MOR',
#   Decimal('-0.396970853'),
#   Decimal('39.46316525'),
#   15),
#  (225,
#   '20/02/2018 05:27:07',
#   3,
#   12,
#   '214_CALLE_SANTA_CRUZ_DE_TENERIFE_ESQ_CALLE_LLOMBA',
#   Decimal('-0.400574875'),
#   Decimal('39.46493226'),
#   15),
#  (226,
#   '20/02/2018 05:27:07',
#   11,
#   9,
#   '35_C/ DUQUE DE CALABRIA',
#   Decimal('-0.366992697'),
#   Decimal('39.46374924'),
#   20),
#  (227,
#   '20/02/2018 05:27:07',
#   18,
#   2,
#   '37_AVDA. PERIS Y VALERO',
#   Decimal('-0.366438956'),
#   Decimal('39.46093775'),
#   20),
#  (228,
#   '20/02/2018 05:27:07',
#   19,
#   0,
#   '39_AVDA. PERIS Y VALERO',
#   Decimal('-0.37392974'),
#   Decimal('39.45785423'),
#   19),
#  (229,
#   '20/02/2018 05:27:07',
#   18,
#   12,
#   '117_PRIMADO REIG',
#   Decimal('-0.357063631'),
#   Decimal('39.47925129'),
#   30),
#  (230,
#   '20/02/2018 05:27:07',
#   3,
#   12,
#   '215_CALLE_MUSICO_AYLLON_ESQ_CALLE_FRANCISCO_DOLZ',
#   Decimal('-0.396746847'),
#   Decimal('39.46567126'),
#   15),
#  (231,
#   '20/02/2018 05:27:07',
#   0,
#   26,
#   '40_CALLE_BARCAS_FRENTE _TEATRO_PRINCIPAL',
#   Decimal('-0.374822738'),
#   Decimal('39.47046627'),
#   26),
#  (232,
#   '20/02/2018 05:27:07',
#   20,
#   0,
#   '41_AVDA. GRAL. URRUTIA',
#   Decimal('-0.364774689'),
#   Decimal('39.45891223'),
#   20),
#  (233,
#   '20/02/2018 05:27:07',
#   18,
#   1,
#   '060_AVDA.BALEARES II',
#   Decimal('-0.351774615'),
#   Decimal('39.46223123'),
#   19),
#  (234,
#   '20/02/2018 05:27:07',
#   20,
#   0,
#   '061_VICENTE VIDAL',
#   Decimal('-0.347828591'),
#   Decimal('39.46129322'),
#   20),
#  (235,
#   '20/02/2018 05:27:07',
#   20,
#   0,
#   '062_MENORCA',
#   Decimal('-0.342150566'),
#   Decimal('39.45981121'),
#   20),
#  (236,
#   '20/02/2018 05:27:07',
#   15,
#   0,
#   '84_SERRERIA_ESQ_PINTOR FERRER CALATAYUD',
#   Decimal('-0.335163524'),
#   Decimal('39.46729423'),
#   15),
#  (237,
#   '20/02/2018 05:27:07',
#   1,
#   22,
#   '085_AVDA_BLASCO IBAÑEZ 1',
#   Decimal('-0.36471367'),
#   Decimal('39.47946429'),
#   23),
#  (238,
#   '20/02/2018 05:27:07',
#   3,
#   15,
#   '86_AVDA_GASPAR_AGUILAR_ESQ_VICENTE_PARRA',
#   Decimal('-0.391191832'),
#   Decimal('39.45524022'),
#   20),
#  (239,
#   '20/02/2018 05:27:07',
#   1,
#   32,
#   '87_AVDA BLASCO IBAÑEZ 2',
#   Decimal('-0.361878658'),
#   Decimal('39.47851828'),
#   33),
#  (240,
#   '20/02/2018 05:27:07',
#   2,
#   18,
#   '118_C/ DR. GOMEZ FERRER',
#   Decimal('-0.360414651'),
#   Decimal('39.48046629'),
#   20),
#  (241,
#   '20/02/2018 05:27:07',
#   15,
#   0,
#   '122_C_MÚSICO HIPÓLITO MARTÍNEZ',
#   Decimal('-0.354064614'),
#   Decimal('39.4844853'),
#   15),
#  (242,
#   '20/02/2018 05:27:07',
#   20,
#   5,
#   '124_C/ AZAGADOR DE ALBORAYA',
#   Decimal('-0.361953654'),
#   Decimal('39.48850132'),
#   25),
#  (243,
#   '20/02/2018 05:27:07',
#   15,
#   0,
#   '125_C/ MASQUEFA',
#   Decimal('-0.358616638'),
#   Decimal('39.48969332'),
#   15),
#  (244,
#   '20/02/2018 05:27:07',
#   14,
#   6,
#   '208_CALLE_CARTEROS_ESQ_CALLE_MOSSEN_FEBRER',
#   Decimal('-0.388576816'),
#   Decimal('39.45169221'),
#   20),
#  (245,
#   '20/02/2018 05:27:07',
#   5,
#   13,
#   '209_AVDA_GASPAR_AGUILAR_ESQ_CALLE_MUSICO_PENELLA',
#   Decimal('-0.393013844'),
#   Decimal('39.45208222'),
#   18),
#  (246,
#   '20/02/2018 05:27:07',
#   7,
#   8,
#   '002_CALLE_SALVADOR_GINER_CALLE_MUSEO',
#   Decimal('-0.37974675'),
#   Decimal('39.4798893'),
#   15),
#  (247,
#   '20/02/2018 05:27:07',
#   5,
#   15,
#   '003_PLAZA_MUSICO_LOPEZ_CHAVARRI',
#   Decimal('-0.380286754'),
#   Decimal('39.47683529'),
#   20),
#  (248,
#   '20/02/2018 05:27:07',
#   3,
#   12,
#   '005_PINTOR_LOPEZ_PZA_POETA_LLORENTE',
#   Decimal('-0.371138706'),
#   Decimal('39.47689528'),
#   15),
#  (249,
#   '20/02/2018 05:27:07',
#   15,
#   1,
#   '020_FERNANDO_EL_CATOLICO_CALLE_QUART',
#   Decimal('-0.387845794'),
#   Decimal('39.47503429'),
#   16),
#  (250,
#   '20/02/2018 05:27:07',
#   25,
#   0,
#   '53_C/ LUIS GARCIA BERLANGA',
#   Decimal('-0.348137598'),
#   Decimal('39.45676421'),
#   25),
#  (251,
#   '20/02/2018 05:27:07',
#   7,
#   13,
#   '119_C/ JAIME ROIG',
#   Decimal('-0.363224662'),
#   Decimal('39.4825203'),
#   20),
#  (252,
#   '20/02/2018 05:27:07',
#   20,
#   0,
#   '126_C/ ALFAUIR',
#   Decimal('-0.360102642'),
#   Decimal('39.49309833'),
#   20),
#  (253,
#   '20/02/2018 05:27:07',
#   3,
#   21,
#   '217_CALLE_9_DE_OCTUBRE_ESQ_CALLE_PINTOR_STOLZ',
#   Decimal('-0.404594888'),
#   Decimal('39.47032828'),
#   25),
#  (254,
#   '20/02/2018 05:27:07',
#   9,
#   6,
#   '218_CALLE_SALVADOR_FERRANDIS_LUNA_ESQ_CALLE_JUAN_B',
#   Decimal('-0.397382857'),
#   Decimal('39.47074028'),
#   15),
#  (255,
#   '20/02/2018 05:27:07',
#   6,
#   12,
#   '219_CALLE_CASTAN_TOBEÑAS_ESQ_CALLE_VELAZQUEZ',
#   Decimal('-0.401591697'),
#   Decimal('39.47282119'),
#   18),
#  (256,
#   '20/02/2018 05:27:07',
#   2,
#   18,
#   '221_AVDA_MANUEL_DE_FALLA_ESQ_CALLE_HERNANDEZ_LAZAR',
#   Decimal('-0.402851877'),
#   Decimal('39.4752703'),
#   20),
#  (257,
#   '20/02/2018 05:27:07',
#   20,
#   0,
#   '222_AVDA_MAESTRO_RODRIGO_ESQ_AVDA_MANUEL_DE_FALLA',
#   Decimal('-0.397280841'),
#   Decimal('39.4768933'),
#   20),
#  (258,
#   '20/02/2018 05:27:07',
#   4,
#   10,
#   '230_CALLE_POETA_SERRANO_CLAVERO_EQ_GENERAL_LLORENS',
#   Decimal('-0.386782783'),
#   Decimal('39.49475036'),
#   15),
#  (259,
#   '20/02/2018 05:27:07',
#   8,
#   7,
#   '231_CALLE_DE_ALCAÑIZ_ESQ_CALLE_CAMBRILS',
#   Decimal('-0.378619733'),
#   Decimal('39.49507235'),
#   15),
#  (260,
#   '20/02/2018 05:27:07',
#   12,
#   3,
#   '232_SAN_VICENTE_DE_PAUL_SANTIAGO_RUSIÑOL',
#   Decimal('-0.365751672'),
#   Decimal('39.49464435'),
#   15),
#  (261,
#   '20/02/2018 05:27:07',
#   18,
#   0,
#   '243_ALBACETE_ESQ_MALUQUER',
#   Decimal('-0.384540784'),
#   Decimal('39.46282024'),
#   18),
#  (262,
#   '20/02/2018 05:27:07',
#   19,
#   0,
#   '167_PAVIA 3',
#   Decimal('-0.324608467'),
#   Decimal('39.47490825'),
#   20),
#  (263,
#   '20/02/2018 05:27:07',
#   8,
#   12,
#   '244_AVDA_PIO_BAROJA_VALLE_DE_LA_BALLESTERA',
#   Decimal('-0.406134895'),
#   Decimal('39.47850631'),
#   20),
#  (264,
#   '20/02/2018 05:27:07',
#   4,
#   10,
#   '245_9_DE_OCTUBRE_CIEZA',
#   Decimal('-0.405549889'),
#   Decimal('39.47206028'),
#   14),
#  (265,
#   '20/02/2018 05:27:07',
#   6,
#   24,
#   '246_AVDA_TRES_CRUCES_ENTRADA_HOSPITAL_GENERAL',
#   Decimal('-0.406507896'),
#   Decimal('39.46909027'),
#   30),
#  (266,
#   '20/02/2018 05:27:07',
#   8,
#   7,
#   '247_AVDA_TRES_CRUCES_MUSICO_AYLLON',
#   Decimal('-0.405571897'),
#   Decimal('39.46741027'),
#   15),
#  (267,
#   '20/02/2018 05:27:07',
#   16,
#   2,
#   '223_CALLE_VALLE_BALLESTERA_ESQ_PLAZA_POLICIA_LOCAL',
#   Decimal('-0.401185865'),
#   Decimal('39.47855831'),
#   20),
#  (268,
#   '20/02/2018 05:27:07',
#   10,
#   9,
#   '224_PLAZA_JOSE_MONFORTE_TUDELA_ESQ_CALLE_HERNANDEZ',
#   Decimal('-0.403586882'),
#   Decimal('39.48056832'),
#   20),
#  (269,
#   '20/02/2018 05:27:07',
#   0,
#   19,
#   '225_CALLE_PADRE_BARRANCO_DESPUES_CALLE_BENIFAIRO',
#   Decimal('-0.401140865'),
#   Decimal('39.48810734'),
#   20),
#  (270,
#   '20/02/2018 05:27:07',
#   0,
#   30,
#   '226_CALLE_SAFOR_ESQ_AVDA_DE_LAS_CORTES_VALENCIANAS',
#   Decimal('-0.398857851'),
#   Decimal('39.49086434'),
#   30),
#  (271,
#   '20/02/2018 05:27:07',
#   2,
#   18,
#   '227_CALLE_SAN_CLEMENTE_ENTRA_HOSPITAL_ARNAU_VILANO',
#   Decimal('-0.402929864'),
#   Decimal('39.49024834'),
#   20),
#  (272,
#   '20/02/2018 05:27:07',
#   2,
#   12,
#   "228_AVDA_NICASIO_BENLLOCH_ESQ_CALLE_L'HORTA_SUD",
#   Decimal('-0.398669838'),
#   Decimal('39.49369236'),
#   15),
#  (273,
#   '20/02/2018 05:27:07',
#   0,
#   24,
#   '004_PLAZA_DE_LA_VIRGEN_CALLE_BAILIA',
#   Decimal('-0.375340736'),
#   Decimal('39.47674728'),
#   25),
#  (274,
#   '20/02/2018 05:27:07',
#   3,
#   17,
#   '007_PZA_DEL_MERCADO_TAULA_DE_CANVIS',
#   Decimal('-0.379183758'),
#   Decimal('39.47487228'),
#   20),
#  (275,
#   '20/02/2018 05:27:07',
#   14,
#   0,
#   '168_AVDA. MALVARROSA',
#   Decimal('-0.327885481'),
#   Decimal('39.47687127'),
#   15),
#  (276,
#   '20/02/2018 05:27:07',
#   0,
#   16,
#   '229_CALLE_AITANA_ESQ_AVDA_BURJASSOT',
#   Decimal('-0.394804819'),
#   Decimal('39.49310435'),
#   16),
#  (277,
#   '20/02/2018 05:27:07',
#   2,
#   18,
#   '248_AVDA_TRES_CRUCES_JOSE_MARIA_MORTES_LERMA',
#   Decimal('-0.404967901'),
#   Decimal('39.46284026'),
#   20),
#  (278,
#   '20/02/2018 05:27:07',
#   5,
#   11,
#   '220_CALLE_CASTAN_TOBEÑAS_ESQ_CALLE_DE_GOYA',
#   Decimal('-0.398319856'),
#   Decimal('39.47385529'),
#   16),
#  (279,
#   '20/02/2018 05:27:07',
#   6,
#   19,
#   '001_GUILLEN_DE_CASTRO',
#   Decimal('-0.382927645'),
#   Decimal('39.48004218'),
#   25),
#  (280,
#   '20/02/2018 05:27:07',
#   9,
#   6,
#   '026_CALLE_SAN_JOSE_DE_CALASANZ',
#   Decimal('-0.386050791'),
#   Decimal('39.46619525'),
#   15),
#  (281,
#   '20/02/2018 05:27:07',
#   7,
#   12,
#   '027_CALLE_SAN_VICENTE_MARTIR_129',
#   Decimal('-0.381849779'),
#   Decimal('39.46336224'),
#   20),
#  (282,
#   '20/02/2018 05:27:07',
#   0,
#   20,
#   '031_CALLE SALAMANCA',
#   Decimal('-0.36502668'),
#   Decimal('39.46736525'),
#   20),
#  (283,
#   '20/02/2018 05:27:07',
#   2,
#   15,
#   '34_AVDA. ANTIGUO REINO DE VALENCIA',
#   Decimal('-0.369959711'),
#   Decimal('39.46412224'),
#   17),
#  (284,
#   '20/02/2018 05:27:07',
#   2,
#   23,
#   '036_PZA_LOS_FUEROS_CONDE_TRENOR',
#   Decimal('-0.375434726'),
#   Decimal('39.4790723'),
#   25),
#  (285,
#   '20/02/2018 05:27:07',
#   12,
#   8,
#   '38_AVDA. PERIS Y VALERO',
#   Decimal('-0.370247717'),
#   Decimal('39.459402'),
#   20),
#  (286,
#   '20/02/2018 05:27:07',
#   17,
#   6,
#   '179_AVENIDA_DE_LA_PLATA_45',
#   Decimal('-0.366424704'),
#   Decimal('39.45547221'),
#   23),
#  (287,
#   '20/02/2018 05:27:07',
#   14,
#   6,
#   '42_AVDA. DE LA PLATA',
#   Decimal('-0.358656653'),
#   Decimal('39.45878122'),
#   20),
#  (288,
#   '20/02/2018 05:27:07',
#   12,
#   7,
#   '44_AVDA. GRAL. URRUTIA',
#   Decimal('-0.363012682'),
#   Decimal('39.45642921'),
#   19),
#  (289,
#   '20/02/2018 05:27:07',
#   18,
#   2,
#   '127_C/ DUQUE DE MANDAS',
#   Decimal('-0.364444669'),
#   Decimal('39.49059132'),
#   20),
#  (290,
#   '20/02/2018 05:27:07',
#   17,
#   8,
#   '128_C/ ALFAUIR',
#   Decimal('-0.367542686'),
#   Decimal('39.48876633'),
#   25),
#  (291,
#   '20/02/2018 05:27:07',
#   16,
#   4,
#   '129_C_ALMAZORA',
#   Decimal('-0.369943701'),
#   Decimal('39.48597531'),
#   20),
#  (292,
#   '20/02/2018 05:27:07',
#   11,
#   4,
#   '130_C/ CONVENTO CARMELITAS',
#   Decimal('-0.370208697'),
#   Decimal('39.4832383'),
#   15),
#  (293,
#   '20/02/2018 05:27:07',
#   1,
#   19,
#   '131_C/ ALBORAYA',
#   Decimal('-0.371161706'),
#   Decimal('39.48065329'),
#   20),
#  (294,
#   '20/02/2018 05:27:07',
#   15,
#   0,
#   '132_C/ RUAYA',
#   Decimal('-0.373432719'),
#   Decimal('39.48528632'),
#   15),
#  (295,
#   '20/02/2018 05:27:07',
#   12,
#   3,
#   '133_C/ ALFAMBRA',
#   Decimal('-0.375880731'),
#   Decimal('39.48275631'),
#   15),
#  (296,
#   '20/02/2018 05:27:07',
#   8,
#   7,
#   '139_C/ REUS',
#   Decimal('-0.382871767'),
#   Decimal('39.48570632'),
#   15),
#  (297,
#   '20/02/2018 05:27:07',
#   11,
#   9,
#   '180_AVENIDA_DOCTOR_WAKSMAN',
#   Decimal('-0.370681716'),
#   Decimal('39.45602122'),
#   20),
#  (298,
#   '20/02/2018 05:27:07',
#   0,
#   30,
#   '189_HOSPITAL_NUEVA_FE',
#   Decimal('-0.375900761'),
#   Decimal('39.44467118'),
#   30),
#  (299,
#   '20/02/2018 05:27:07',
#   7,
#   11,
#   '190_CTRA_MALILLA',
#   Decimal('-0.380294778'),
#   Decimal('39.44608219'),
#   18),
#  (300,
#   '20/02/2018 05:27:07',
#   7,
#   8,
#   '191_CTRA_MALILLA',
#   Decimal('-0.378864768'),
#   Decimal('39.4503292'),
#   15),
#  (301,
#   '20/02/2018 05:27:07',
#   2,
#   18,
#   '014_BARÓN CARCER',
#   Decimal('-0.379722766'),
#   Decimal('39.46896726'),
#   20),
#  (302,
#   '20/02/2018 05:27:07',
#   15,
#   0,
#   '072_RAMIRO MAETZU',
#   Decimal('-0.346306584'),
#   Decimal('39.46724424'),
#   15),
#  (303,
#   '20/02/2018 05:27:07',
#   20,
#   0,
#   '073_JERONIMO MONSORIU',
#   Decimal('-0.342877568'),
#   Decimal('39.46625924'),
#   20),
#  (304,
#   '20/02/2018 05:27:07',
#   18,
#   2,
#   '074_PLAZA SAN FELIPE NERI',
#   Decimal('-0.353732624'),
#   Decimal('39.46994926'),
#   20),
#  (305,
#   '20/02/2018 05:27:07',
#   20,
#   5,
#   '075_CAMPOAMOR I',
#   Decimal('-0.351699605'),
#   Decimal('39.47211326'),
#   25),
#  (306,
#   '20/02/2018 05:27:07',
#   19,
#   0,
#   '076_CAMPOAMOR II',
#   Decimal('-0.343459561'),
#   Decimal('39.47008324'),
#   19),
#  (307,
#   '20/02/2018 05:27:07',
#   19,
#   0,
#   '77_C/ MOLINELL',
#   Decimal('-0.365665673'),
#   Decimal('39.48497331'),
#   20),
#  (308,
#   '20/02/2018 05:27:07',
#   6,
#   9,
#   '181_CALLE_DEL_SALINAR',
#   Decimal('-0.36818971'),
#   Decimal('39.45799922'),
#   15),
#  (309,
#   '20/02/2018 05:27:07',
#   6,
#   14,
#   '078_AVDA. ARAGÓN I',
#   Decimal('-0.358686642'),
#   Decimal('39.46994526'),
#   20),
#  (310,
#   '20/02/2018 05:27:07',
#   0,
#   20,
#   '079_AVDA. ARAGON II',
#   Decimal('-0.357240642'),
#   Decimal('39.47277926'),
#   20),
#  (311,
#   '20/02/2018 05:27:07',
#   2,
#   23,
#   '080_AMADEO SAVOIA',
#   Decimal('-0.362296669'),
#   Decimal('39.47374227'),
#   25),
#  (312,
#   '20/02/2018 05:27:07',
#   1,
#   19,
#   '081_DOCTOR FORNOS',
#   Decimal('-0.360976656'),
#   Decimal('39.47512828'),
#   20),
#  (313,
#   '20/02/2018 05:27:07',
#   22,
#   3,
#   '150_DR. MANUEL CANDELA',
#   Decimal('-0.35060761'),
#   Decimal('39.46772125'),
#   25),
#  (314,
#   '20/02/2018 05:27:07',
#   20,
#   0,
#   '151_JERONIMO MONSORIU',
#   Decimal('-0.33711553'),
#   Decimal('39.46466923'),
#   20),
#  (315,
#   '20/02/2018 05:27:07',
#   10,
#   5,
#   '152_C/ LITERATO AZORÍN',
#   Decimal('-0.372703728'),
#   Decimal('39.46092523'),
#   15),
#  (316,
#   '20/02/2018 05:27:07',
#   4,
#   20,
#   '153_C/ LLANO DE ZAIDA',
#   Decimal('-0.380170751'),
#   Decimal('39.48316231'),
#   24),
#  (317,
#   '20/02/2018 05:27:07',
#   14,
#   0,
#   '154_PESCADORES',
#   Decimal('-0.329552492'),
#   Decimal('39.46987624'),
#   15),
#  (318,
#   '20/02/2018 05:27:07',
#   12,
#   8,
#   '155_C/ SALAMANCA',
#   Decimal('-0.363076673'),
#   Decimal('39.46495324'),
#   20),
#  (319,
#   '20/02/2018 05:27:07',
#   11,
#   10,
#   '182_AVDA_AUSIAS_MARCH',
#   Decimal('-0.374963743'),
#   Decimal('39.45543222'),
#   21),
#  (320,
#   '20/02/2018 05:27:07',
#   14,
#   0,
#   '199_CALLE_BEATO_NICOLAS_FACTOR',
#   Decimal('-0.391556832'),
#   Decimal('39.46158824'),
#   15),
#  (321,
#   '20/02/2018 05:27:07',
#   3,
#   12,
#   '200_AVDA_DEL_CID',
#   Decimal('-0.393212835'),
#   Decimal('39.46773727'),
#   15),
#  (322,
#   '20/02/2018 05:27:07',
#   16,
#   4,
#   '201_AVDA_PEREZ_GALDOS',
#   Decimal('-0.393666836'),
#   Decimal('39.47171228'),
#   20),
#  (323,
#   '20/02/2018 05:27:07',
#   17,
#   0,
#   '164_PAVIA 1',
#   Decimal('-0.324632463'),
#   Decimal('39.46846023'),
#   17),
#  (324,
#   '20/02/2018 05:27:07',
#   17,
#   3,
#   '165_PAVIA 2',
#   Decimal('-0.324568469'),
#   Decimal('39.47140924'),
#   20),
#  (325,
#   '20/02/2018 05:27:07',
#   13,
#   1,
#   '166_PROGRESO',
#   Decimal('-0.328809486'),
#   Decimal('39.47334925'),
#   15),
#  (326,
#   '20/02/2018 05:27:07',
#   3,
#   12,
#   '006_GUILLEN_CASTRO_CON_CALLE_SAN_PEDRO_PASCUAL',
#   Decimal('-0.384081776'),
#   Decimal('39.47279828'),
#   15),
#  (327,
#   '20/02/2018 05:27:07',
#   1,
#   21,
#   '008_PLAZA_DE_LA_REINA_ESQUINA_CALLE_DEL_MAR',
#   Decimal('-0.375082731'),
#   Decimal('39.47432028'),
#   23),
#  (328,
#   '20/02/2018 05:27:07',
#   1,
#   24,
#   '009_PLAZA_TETUAN_4',
#   Decimal('-0.369928706'),
#   Decimal('39.47435527'),
#   25),
#  (329,
#   '20/02/2018 05:27:07',
#   0,
#   15,
#   '010_CALLE_DEL_HOSPITAL_FRENTE_CALLE_HORNO_DEL_HOSP',
#   Decimal('-0.382608768'),
#   Decimal('39.47081627'),
#   15),
#  (330,
#   '20/02/2018 05:27:07',
#   10,
#   8,
#   '183_AVDA_AUSIAS_MARCH',
#   Decimal('-0.372282729'),
#   Decimal('39.45262021'),
#   18),
#  (331,
#   '20/02/2018 05:27:07',
#   2,
#   25,
#   '011_PZA_AYTO_CON_CALLE_COTANDA',
#   Decimal('-0.37678274'),
#   Decimal('39.47118627'),
#   27),
#  (332,
#   '20/02/2018 05:27:07',
#   1,
#   18,
#   '012_CALLE_MINYANA',
#   Decimal('-0.374008636'),
#   Decimal('39.47196717'),
#   20),
#  (333,
#   '20/02/2018 05:27:07',
#   1,
#   23,
#   '013_PZA. ALFONSO MAGNANIMO_CON_CALLE_LA_NAVE',
#   Decimal('-0.370872714'),
#   Decimal('39.47206227'),
#   24),
#  (334,
#   '20/02/2018 05:27:07',
#   2,
#   18,
#   '016_COLON I',
#   Decimal('-0.370431713'),
#   Decimal('39.47009226'),
#   20),
#  (335,
#   '20/02/2018 05:27:07',
#   2,
#   38,
#   '017_ESTACION RENFE I',
#   Decimal('-0.377257743'),
#   Decimal('39.46746826'),
#   40),
#  (336,
#   '20/02/2018 05:27:07',
#   1,
#   23,
#   '018_COLON II',
#   Decimal('-0.37312773'),
#   Decimal('39.46819126'),
#   24),
#  (337,
#   '20/02/2018 05:27:07',
#   11,
#   9,
#   '43_C/ DE ORIENTE',
#   Decimal('-0.361151664'),
#   Decimal('39.45947722'),
#   20),
#  (338,
#   '20/02/2018 05:27:07',
#   7,
#   8,
#   '082_GUILLEN_DE_CASTRO_TORRES_DE_QUART',
#   Decimal('-0.383912777'),
#   Decimal('39.47605629'),
#   15),
#  (339,
#   '20/02/2018 05:27:07',
#   11,
#   4,
#   '156_C/ CUBA',
#   Decimal('-0.37634375'),
#   Decimal('39.46096424'),
#   15),
#  (340,
#   '20/02/2018 05:27:07',
#   6,
#   14,
#   '157_AVENIDA_PEREZ_GALDOS',
#   Decimal('-0.387364808'),
#   Decimal('39.46405225'),
#   20),
#  (341,
#   '20/02/2018 05:27:07',
#   6,
#   8,
#   '184_CALLE_BOMBER_RAMON_DUART',
#   Decimal('-0.365568699'),
#   Decimal('39.45278221'),
#   15),
#  (342,
#   '20/02/2018 05:27:07',
#   15,
#   0,
#   '158_DR.LLUNCH',
#   Decimal('-0.327717488'),
#   Decimal('39.46669823'),
#   15),
#  (343,
#   '20/02/2018 05:27:07',
#   17,
#   0,
#   '159_FRANCISCO CUBELLS',
#   Decimal('-0.334720526'),
#   Decimal('39.46344922'),
#   17),
#  (344,
#   '20/02/2018 05:27:07',
#   20,
#   0,
#   '160_JOSE MARIA DE HARO',
#   Decimal('-0.338979542'),
#   Decimal('39.46733624'),
#   20),
#  (345,
#   '20/02/2018 05:27:07',
#   15,
#   0,
#   '161_MEDITERRANEO',
#   Decimal('-0.331724504'),
#   Decimal('39.46796924'),
#   15),
#  (346,
#   '20/02/2018 05:27:07',
#   18,
#   1,
#   '162_PZA. ARMADA ESPAÑOLA',
#   Decimal('-0.329793499'),
#   Decimal('39.46360422'),
#   19),
#  (347,
#   '20/02/2018 05:27:07',
#   17,
#   3,
#   '163_PASEO NEPTUNO',
#   Decimal('-0.323399465'),
#   Decimal('39.46443722'),
#   20),
#  (348,
#   '20/02/2018 05:27:07',
#   0,
#   25,
#   '028_NAVARRO REVERTE',
#   Decimal('-0.367749696'),
#   Decimal('39.47158227'),
#   25),
#  (349,
#   '20/02/2018 05:27:07',
#   1,
#   19,
#   '029_PLAZA AMERICA',
#   Decimal('-0.365297677'),
#   Decimal('39.47011226'),
#   20),
#  (350,
#   '20/02/2018 05:27:07',
#   1,
#   19,
#   '030_CIRILO AMOROS',
#   Decimal('-0.368497698'),
#   Decimal('39.46860126'),
#   20),
#  (351,
#   '20/02/2018 05:27:07',
#   9,
#   11,
#   '032_C/ CONDE DE ALTEA',
#   Decimal('-0.368245697'),
#   Decimal('39.46600625'),
#   20),
#  (352,
#   '20/02/2018 05:27:07',
#   7,
#   8,
#   '185_AVDA_AUSIAS_MARCH',
#   Decimal('-0.370501719'),
#   Decimal('39.4500442'),
#   15),
#  (353,
#   '20/02/2018 05:27:07',
#   4,
#   16,
#   '033_GRAN_VIA_GERMANIAS_ESQ_CALLE_RUZAFA',
#   Decimal('-0.373988738'),
#   Decimal('39.46481825'),
#   20),
#  (354,
#   '20/02/2018 05:27:07',
#   10,
#   5,
#   '45_AVDA. GRAL. URRUTIA',
#   Decimal('-0.361853674'),
#   Decimal('39.4538192'),
#   15),
#  (355,
#   '20/02/2018 05:27:07',
#   17,
#   3,
#   '46_AVDA. INSTITUTO OBRERO DE VALENCIA',
#   Decimal('-0.35878566'),
#   Decimal('39.45550921'),
#   20),
#  (356,
#   '20/02/2018 05:27:07',
#   0,
#   20,
#   '47_AVDA. AUTOPISTA DEL SALER',
#   Decimal('-0.355416639'),
#   Decimal('39.45651221'),
#   20),
#  (357,
#   '20/02/2018 05:27:07',
#   1,
#   19,
#   '48_AVDA. ANTONIO FERRANDIS',
# ...
#   Decimal('-0.361151664'),
#   Decimal('39.45947722'),
#   20),
#  (884,
#   '20/02/2018 05:56:30',
#   7,
#   8,
#   '082_GUILLEN_DE_CASTRO_TORRES_DE_QUART',
#   Decimal('-0.383912777'),
#   Decimal('39.47605629'),
#   15),
#  (885,
#   '20/02/2018 05:56:30',
#   12,
#   3,
#   '156_C/ CUBA',
#   Decimal('-0.37634375'),
#   Decimal('39.46096424'),
#   15),
#  (886,
#   '20/02/2018 05:56:30',
#   6,
#   14,
#   '157_AVENIDA_PEREZ_GALDOS',
#   Decimal('-0.387364808'),
#   Decimal('39.46405225'),
#   20),
#  (887,
#   '20/02/2018 05:56:30',
#   6,
#   9,
#   '181_CALLE_DEL_SALINAR',
#   Decimal('-0.36818971'),
#   Decimal('39.45799922'),
#   15),
#  (888,
#   '20/02/2018 05:56:30',
#   15,
#   0,
#   '158_DR.LLUNCH',
#   Decimal('-0.327717488'),
#   Decimal('39.46669823'),
#   15),
#  (889,
#   '20/02/2018 05:56:30',
#   17,
#   0,
#   '159_FRANCISCO CUBELLS',
#   Decimal('-0.334720526'),
#   Decimal('39.46344922'),
#   17),
#  (890,
#   '20/02/2018 05:56:30',
#   20,
#   0,
#   '160_JOSE MARIA DE HARO',
#   Decimal('-0.338979542'),
#   Decimal('39.46733624'),
#   20),
#  (891,
#   '20/02/2018 05:56:30',
#   15,
#   0,
#   '161_MEDITERRANEO',
#   Decimal('-0.331724504'),
#   Decimal('39.46796924'),
#   15),
#  (892,
#   '20/02/2018 05:56:30',
#   18,
#   1,
#   '162_PZA. ARMADA ESPAÑOLA',
#   Decimal('-0.329793499'),
#   Decimal('39.46360422'),
#   19),
#  (893,
#   '20/02/2018 05:56:30',
#   17,
#   3,
#   '163_PASEO NEPTUNO',
#   Decimal('-0.323399465'),
#   Decimal('39.46443722'),
#   20),
#  (894,
#   '20/02/2018 05:56:30',
#   0,
#   25,
#   '028_NAVARRO REVERTE',
#   Decimal('-0.367749696'),
#   Decimal('39.47158227'),
#   25),
#  (895,
#   '20/02/2018 05:56:30',
#   1,
#   19,
#   '029_PLAZA AMERICA',
#   Decimal('-0.365297677'),
#   Decimal('39.47011226'),
#   20),
#  (896,
#   '20/02/2018 05:56:30',
#   1,
#   19,
#   '030_CIRILO AMOROS',
#   Decimal('-0.368497698'),
#   Decimal('39.46860126'),
#   20),
#  (897,
#   '20/02/2018 05:56:30',
#   9,
#   11,
#   '032_C/ CONDE DE ALTEA',
#   Decimal('-0.368245697'),
#   Decimal('39.46600625'),
#   20),
#  (898,
#   '20/02/2018 05:56:30',
#   11,
#   10,
#   '182_AVDA_AUSIAS_MARCH',
#   Decimal('-0.374963743'),
#   Decimal('39.45543222'),
#   21),
#  (899,
#   '20/02/2018 05:56:30',
#   4,
#   16,
#   '033_GRAN_VIA_GERMANIAS_ESQ_CALLE_RUZAFA',
#   Decimal('-0.373988738'),
#   Decimal('39.46481825'),
#   20),
#  (900,
#   '20/02/2018 05:56:30',
#   10,
#   5,
#   '45_AVDA. GRAL. URRUTIA',
#   Decimal('-0.361853674'),
#   Decimal('39.4538192'),
#   15),
#  (901,
#   '20/02/2018 05:56:30',
#   18,
#   2,
#   '46_AVDA. INSTITUTO OBRERO DE VALENCIA',
#   Decimal('-0.35878566'),
#   Decimal('39.45550921'),
#   20),
#  (902,
#   '20/02/2018 05:56:30',
#   0,
#   20,
#   '47_AVDA. AUTOPISTA DEL SALER',
#   Decimal('-0.355416639'),
#   Decimal('39.45651221'),
#   20),
#  (903,
#   '20/02/2018 05:56:30',
#   1,
#   19,
#   '48_AVDA. ANTONIO FERRANDIS',
#   Decimal('-0.358551054'),
#   Decimal('39.4508073'),
#   20),
#  (904,
#   '20/02/2018 05:56:30',
#   2,
#   23,
#   '49_C/ RICARDO MUÑOZ SUAY',
#   Decimal('-0.357108729'),
#   Decimal('39.45298688'),
#   25),
#  (905,
#   '20/02/2018 05:56:30',
#   23,
#   17,
#   '50_AVDA. AUTOPISTA DEL SALER',
#   Decimal('-0.35285763'),
#   Decimal('39.4533182'),
#   40),
#  (906,
#   '20/02/2018 05:56:30',
#   1,
#   19,
#   '51_PSO. DE LAS MORERAS',
#   Decimal('-0.347225603'),
#   Decimal('39.45218319'),
#   20),
#  (907,
#   '20/02/2018 05:56:30',
#   2,
#   18,
#   '058_PLAZA DE ESPAÑA',
#   Decimal('-0.381584767'),
#   Decimal('39.46621825'),
#   20),
#  (908,
#   '20/02/2018 05:56:30',
#   0,
#   30,
#   '89_AVDA. BLASCO IBAÑEZ',
#   Decimal('-0.35931664'),
#   Decimal('39.47780228'),
#   30),
#  (909,
#   '20/02/2018 05:56:30',
#   13,
#   1,
#   '022_JUAN_LLORENS_57',
#   Decimal('-0.388351806'),
#   Decimal('39.46978727'),
#   15),
#  (910,
#   '20/02/2018 05:56:30',
#   0,
#   40,
#   '90_AVDA. BLASCO IBAÑEZ',
#   Decimal('-0.358965641'),
#   Decimal('39.47673428'),
#   40),
#  (911,
#   '20/02/2018 05:56:30',
#   4,
#   11,
#   '091_CALLE_GRABADOR_JORDAN_46_PLAZA_ESCULTOR_PASTOR',
#   Decimal('-0.367571708'),
#   Decimal('39.44412518'),
#   15),
#  (912,
#   '20/02/2018 05:56:30',
#   3,
#   17,
#   '092_AVDA. DE ARAGON, 4 - ESQ AVDA BLASCO IBAÑEZ',
#   Decimal('-0.355966629'),
#   Decimal('39.47586027'),
#   20),
#  (913,
#   '20/02/2018 05:56:30',
#   34,
#   4,
#   '93_AVADA_BLASCO_IBAÑEZ_DESP_C_POETA_DURAN_TORTAJAD',
#   Decimal('-0.343807568'),
#   Decimal('39.47228225'),
#   38),
#  (914,
#   '20/02/2018 05:56:30',
#   10,
#   9,
#   '094_AVDA. BLASCO IBAÑEZ 5',
#   Decimal('-0.351581605'),
#   Decimal('39.47537827'),
#   20),
#  (915,
#   '20/02/2018 05:56:30',
#   0,
#   36,
#   '95_AVDA. DE LOS NARANJOS',
#   Decimal('-0.346117577'),
#   Decimal('39.47983528'),
#   36),
#  (916,
#   '20/02/2018 05:56:30',
#   9,
#   12,
#   '096_AVDA. BLASCO IBAÑEZ 6',
#   Decimal('-0.348212588'),
#   Decimal('39.47355427'),
#   21),
#  (917,
#   '20/02/2018 05:56:30',
#   22,
#   1,
#   '097_AVDA. BLASCO IBAÑEZ 7',
#   Decimal('-0.343130557'),
#   Decimal('39.47306826'),
#   23),
#  (918,
#   '20/02/2018 05:56:30',
#   14,
#   1,
#   '098_SANTOS JUSTO Y PASTOR',
#   Decimal('-0.348440592'),
#   Decimal('39.46968025'),
#   15),
#  (919,
#   '20/02/2018 05:56:30',
#   16,
#   3,
#   '134_C/ MAXIMILIANO THOUS',
#   Decimal('-0.373337716'),
#   Decimal('39.48765632'),
#   20),
#  (920,
#   '20/02/2018 05:56:30',
#   6,
#   14,
#   '024_GRAN_VIA_RAMON_Y_CAJAL',
#   Decimal('-0.384025777'),
#   Decimal('39.46907726'),
#   20),
#  (921,
#   '20/02/2018 05:56:30',
#   19,
#   1,
#   '135_AVDA. CONSTITUCIÓN',
#   Decimal('-0.378499737'),
#   Decimal('39.48570232'),
#   20),
#  (922,
#   '20/02/2018 05:56:30',
#   12,
#   8,
#   '136_CALLE_ECONOMISTA_GAY',
#   Decimal('-0.375608722'),
#   Decimal('39.48994133'),
#   20),
#  (923,
#   '20/02/2018 05:56:30',
#   12,
#   8,
#   '137_CALLE_ECONOMISTA_GAY',
#   Decimal('-0.379894747'),
#   Decimal('39.48903333'),
#   20),
#  (924,
#   '20/02/2018 05:56:30',
#   5,
#   15,
#   '138_SAN_PANCRACIO',
#   Decimal('-0.384220766'),
#   Decimal('39.48819033'),
#   20),
#  (925,
#   '20/02/2018 05:56:30',
#   13,
#   7,
#   '140_AVENIDA_CAMPANAR',
#   Decimal('-0.389598803'),
#   Decimal('39.48800434'),
#   20),
#  (926,
#   '20/02/2018 05:56:30',
#   17,
#   3,
#   '141_C/ GREGORIO GEA (PEATONAL)',
#   Decimal('-0.385154784'),
#   Decimal('39.48326831'),
#   20),
#  (927,
#   '20/02/2018 05:56:30',
#   2,
#   23,
#   '142_C/ GREGORIO GEA (PEATONAL)',
#   Decimal('-0.389657798'),
#   Decimal('39.48192031'),
#   25),
#  (928,
#   '20/02/2018 05:56:30',
#   2,
#   28,
#   '143_AVDA. MENENDEZ PIDAL',
#   Decimal('-0.390934815'),
#   Decimal('39.4795373'),
#   30),
#  (929,
#   '20/02/2018 05:56:30',
#   1,
#   14,
#   '144_CALLE_MARQUES_DE_SAN_JUAN',
#   Decimal('-0.395478836'),
#   Decimal('39.4787793'),
#   15),
#  (930,
#   '20/02/2018 05:56:30',
#   0,
#   0,
#   '145_PLAZA_BADAJOZ',
#   Decimal('-0.398393845'),
#   Decimal('39.48154732'),
#   15),
#  (931,
#   '20/02/2018 05:56:30',
#   10,
#   6,
#   '021_JUAN_LLORENS_29',
#   Decimal('-0.390212816'),
#   Decimal('39.47237128'),
#   16),
#  (932,
#   '20/02/2018 05:56:30',
#   10,
#   13,
#   '025_CALLE_DEL_ALBERIC',
#   Decimal('-0.388608811'),
#   Decimal('39.46772926'),
#   23),
#  (933,
#   '20/02/2018 05:56:30',
#   0,
#   26,
#   '146_AVDA. CAMPANAR',
#   Decimal('-0.390950813'),
#   Decimal('39.48511032'),
#   26),
#  (934,
#   '20/02/2018 05:56:30',
#   4,
#   11,
#   '147_CALLE_PIE_DE_LA_CRUZ_CALLE_DE_LA_REJA',
#   Decimal('-0.380205754'),
#   Decimal('39.47320128'),
#   15),
#  (935,
#   '20/02/2018 05:56:30',
#   20,
#   0,
#   '149_AVDA. PERIS Y VALERO',
#   Decimal('-0.361793668'),
#   Decimal('39.46293423'),
#   20),
#  (936,
#   '20/02/2018 05:56:30',
#   16,
#   2,
#   '169_PAVIA 4',
#   Decimal('-0.324643465'),
#   Decimal('39.47878526'),
#   20),
#  (937,
#   '20/02/2018 05:56:30',
#   18,
#   1,
#   '170_PAVIA 5',
#   Decimal('-0.325332461'),
#   Decimal('39.48297329'),
#   20),
#  (938,
#   '20/02/2018 05:56:30',
#   15,
#   0,
#   '171_CALLE GRAN CANARIA',
#   Decimal('-0.329006481'),
#   Decimal('39.48306028'),
#   15),
#  (939,
#   '20/02/2018 05:56:30',
#   0,
#   20,
#   '172_AVENIDA_PIO_XII',
#   Decimal('-0.39334382'),
#   Decimal('39.48146232'),
#   20),
#  (940,
#   '20/02/2018 05:56:30',
#   3,
#   17,
#   '173_AVENIDA_PIO_XII_34',
#   Decimal('-0.394676822'),
#   Decimal('39.48454132'),
#   20),
#  (941,
#   '20/02/2018 05:56:30',
#   7,
#   12,
#   '174_CALLE_MONDUBER',
#   Decimal('-0.386645778'),
#   Decimal('39.48943834'),
#   19),
#  (942,
#   '20/02/2018 05:56:30',
#   5,
#   10,
#   '175_CALLE_JUAN_XXIII',
#   Decimal('-0.382710754'),
#   Decimal('39.49258934'),
#   15),
#  (943,
#   '20/02/2018 05:56:30',
#   18,
#   7,
#   '52_C/ LUIS GARCIA BERLANGA',
#   Decimal('-0.346338594'),
#   Decimal('39.4560342'),
#   25),
#  (944,
#   '20/02/2018 05:56:30',
#   16,
#   4,
#   '176_CAMINO_DE_MONCADA_52',
#   Decimal('-0.378851744'),
#   Decimal('39.49201734'),
#   20),
#  (945,
#   '20/02/2018 05:56:30',
#   14,
#   1,
#   '177_CALLE_ALCUDIA',
#   Decimal('-0.373486712'),
#   Decimal('39.49354534'),
#   15),
#  (946,
#   '20/02/2018 05:56:30',
#   16,
#   4,
#   '178_CALLE_REIG_GENOVES',
#   Decimal('-0.370504696'),
#   Decimal('39.49221634'),
#   20),
#  (947,
#   '20/02/2018 05:56:30',
#   7,
#   13,
#   '192_CTRA_MALILLA',
#   Decimal('-0.378712765'),
#   Decimal('39.45263721'),
#   20),
#  (948,
#   '20/02/2018 05:56:30',
#   17,
#   3,
#   '193_CALLE_CARTEROS',
#   Decimal('-0.386716801'),
#   Decimal('39.45514622'),
#   20),
#  (949,
#   '20/02/2018 05:56:30',
#   3,
#   37,
#   '194_ESTACION_AVE_JOAQUIN_SOROLLA',
#   Decimal('-0.380972776'),
#   Decimal('39.46101824'),
#   40),
#  (950,
#   '20/02/2018 05:56:30',
#   11,
#   5,
#   '195_CALLE_GIORGETA',
#   Decimal('-0.384279785'),
#   Decimal('39.45938424'),
#   16),
#  (951,
#   '20/02/2018 05:56:30',
#   6,
#   8,
#   '249_AVDA_TRES_CRUCES_SEGUNDA_REPUBLICA_ESPAÑOLA',
#   Decimal('-0.402738884'),
#   Decimal('39.45950624'),
#   15),
#  (952,
#   '20/02/2018 05:56:30',
#   9,
#   6,
#   '250_AVDA_TRES_CRUCES_PIO_XI',
#   Decimal('-0.400805409'),
#   Decimal('39.45635219'),
#   15),
#  (953,
#   '20/02/2018 05:56:30',
#   14,
#   1,
#   '251_ARQUITECTO_SEGURA_LAGO_CAMINO_NUEVO_DE_PICAÑA',
#   Decimal('-0.404411904'),
#   Decimal('39.45583023'),
#   15),
#  (954,
#   '20/02/2018 05:56:30',
#   20,
#   0,
#   '068_AVDA. DEL PUERTO IV',
#   Decimal('-0.341731567'),
#   Decimal('39.46280322'),
#   20),
#  (955,
#   '20/02/2018 05:56:30',
#   11,
#   4,
#   '256_AVDA_TRES_FORQUES_TURIS',
#   Decimal('-0.392233832'),
#   Decimal('39.46396325'),
#   15),
#  (956,
#   '20/02/2018 05:56:30',
#   0,
#   20,
#   '257_PLAZA_SALVADOR_SORIA_ESQ_PIO_X',
#   Decimal('-0.389102828'),
#   Decimal('39.44525119'),
#   20),
#  (957,
#   '20/02/2018 05:56:30',
#   14,
#   1,
#   '258_PINTOR_RAFAEL_SOLVES_ESQ_JOSE_SOTO_MICO',
#   Decimal('-0.389135824'),
#   Decimal('39.43982817'),
#   15),
#  (958,
#   '20/02/2018 05:56:30',
#   17,
#   2,
#   '259_CALLE_PIO_IX_POLIDEPORTIVO_RAMBLETA',
#   Decimal('-0.393013851'),
#   Decimal('39.44546019'),
#   20),
#  (959,
#   '20/02/2018 05:56:30',
#   0,
#   20,
#   '260_DELS_FERRERS_ESQ_TRAGINERS',
#   Decimal('-0.407215907'),
#   Decimal('39.45955624'),
#   20),
#  (960,
#   '20/02/2018 05:56:30',
#   18,
#   1,
#   '261_PZA_XUQUER_ESQ_VINALOPO',
#   Decimal('-0.350375598'),
#   Decimal('39.47667627'),
#   19),
#  (961,
#   '20/02/2018 05:56:30',
#   2,
#   18,
#   '262_AVDA_TRES_FORQUES_COLONIA_ESPANOLA_DE_MEXICO',
#   Decimal('-0.409223923'),
#   Decimal('39.46347226'),
#   20),
#  (962,
#   '20/02/2018 05:56:30',
#   6,
#   9,
#   '267_C_BENIFERRI_VICENTE_TOMAS_MARTI',
#   Decimal('-0.405927882'),
#   Decimal('39.49416836'),
#   16),
#  (963,
#   '20/02/2018 05:56:30',
#   7,
#   9,
#   '270_CALLE_NINOT_ESQ_PZA_REGINO_MAS',
#   Decimal('-0.392887812'),
#   Decimal('39.50007537'),
#   16),
#  (964,
#   '20/02/2018 05:56:30',
#   4,
#   11,
#   '271_CALLE_SALVADOR_CERVERÓ_CALLE_CARLOS_CORTINA',
#   Decimal('-0.389889787'),
#   Decimal('39.49927937'),
#   15),
#  (965,
#   '20/02/2018 05:56:30',
#   24,
#   1,
#   '069_AVDA. DEL PUERTO',
#   Decimal('-0.338719545'),
#   Decimal('39.46195222'),
#   25),
#  (966,
#   '20/02/2018 05:56:30',
#   4,
#   11,
#   '273_CALLE_MORAIRA_CALLE_DALT_DE_LA_MAR',
#   Decimal('-0.333270519'),
#   Decimal('39.45030518'),
#   15),
#  (967,
#   '20/02/2018 05:56:30',
#   7,
#   8,
#   '274_MANUEL_ANDRES_CASTELL_DE_POLOP',
#   Decimal('-0.333186523'),
#   Decimal('39.44807017'),
#   15),
#  (968,
#   '20/02/2018 05:56:30',
#   20,
#   0,
#   '275_CAMINO_DE_LAS_MORERAS_ESQ_RONDA_DE_NAZARET',
#   Decimal('-0.335063538'),
#   Decimal('39.45230519'),
#   20),
#  (969,
#   '20/02/2018 05:56:30',
#   14,
#   6,
#   '276_EDIFICIO_VELES_E_VENTS',
#   Decimal('-0.323763469'),
#   Decimal('39.46197521'),
#   20),
#  (970,
#   '20/02/2018 05:56:30',
#   20,
#   0,
#   '252_DE_LOS_GREMIOS_CAMPOS_CRESPO',
#   Decimal('-0.403572893'),
#   Decimal('39.45028822'),
#   20),
#  (971,
#   '20/02/2018 05:56:30',
#   14,
#   1,
#   '253_PLAZA_JOSE_MELIA_CASTELLO_CAMPOS_CRESPO',
#   Decimal('-0.401099884'),
#   Decimal('39.45272622'),
#   15),
#  (972,
#   '20/02/2018 05:56:30',
#   8,
#   11,
#   '254_AVDA_DR_TOMAS_SALA_CARTEROS',
#   Decimal('-0.389915824'),
#   Decimal('39.4477142'),
#   19),
#  (973,
#   '20/02/2018 05:56:30',
#   3,
#   15,
#   '255_SAN_VICENTE_MARTIR_TOMAS_DE_VILLAROYA',
#   Decimal('-0.386027802'),
#   Decimal('39.4477032'),
#   18),
#  (974,
#   '20/02/2018 05:56:30',
#   14,
#   4,
#   '263_PADRE ESTEBAN_PERNET_ANTES_CASA_MISERICORDIA',
#   Decimal('-0.409642916'),
#   Decimal('39.46704327'),
#   18),
#  (975,
#   '20/02/2018 05:56:30',
#   7,
#   9,
#   '264_AVDA_CID_ANTES_MARCONI',
#   Decimal('-0.414430941'),
#   Decimal('39.46916028'),
#   20),
#  (976,
#   '20/02/2018 05:56:30',
#   10,
#   8,
#   '183_AVDA_AUSIAS_MARCH',
#   Decimal('-0.372282729'),
#   Decimal('39.45262021'),
#   18),
#  (977,
#   '20/02/2018 05:56:30',
#   1,
#   14,
#   '265_C_ALCASSER_POETA_ALBERTO_LISTA',
#   Decimal('-0.408115904'),
#   Decimal('39.47097329'),
#   15),
#  (978,
#   '20/02/2018 05:56:30',
#   13,
#   5,
#   '266_PLANA_ALTA_ESQ_AVDA_MAESTRO_RODRIGO',
#   Decimal('-0.406369883'),
#   Decimal('39.49028935'),
#   18),
#  (979,
#   '20/02/2018 05:56:30',
#   14,
#   0,
#   '233_SAN_JUAN_BOSCO_SANTIAGO_RUSIÑOL',
#   Decimal('-0.369435682'),
#   Decimal('39.49716035'),
#   15),
#  (980,
#   '20/02/2018 05:56:30',
#   15,
#   0,
#   '234_PLAZA MUSICO_ESPI_JOSE_ESTEVE',
#   Decimal('-0.373642712'),
#   Decimal('39.49649935'),
#   15),
#  (981,
#   '20/02/2018 05:56:30',
#   10,
#   5,
#   '235_CONDE_DE_TORREFIEL_CECILIO_PLA',
#   Decimal('-0.377201722'),
#   Decimal('39.49804536'),
#   15),
#  (982,
#   '20/02/2018 05:56:30',
#   10,
#   4,
#   '236_RIO_SEGRE_RAFAEL_COMPANY',
#   Decimal('-0.382276757'),
#   Decimal('39.49506635'),
#   15),
#  (983,
#   '20/02/2018 05:56:30',
#   3,
#   12,
#   '237_LEVANTE_UD_AVDA_ECUADOR',
#   Decimal('-0.391036799'),
#   Decimal('39.49475835'),
#   15),
#  (984,
#   '20/02/2018 05:56:30',
#   6,
#   9,
#   '238_SAN_JOSE_ARTESANO_FRANCISCO_MOROTE_GREUS',
#   Decimal('-0.394381819'),
#   Decimal('39.49744937'),
#   15),
#  (985,
#   '20/02/2018 05:56:30',
#   1,
#   19,
#   '239_LA_FLORISTA_TRANVIA_PALACIO_CONGRESOS',
#   Decimal('-0.39996285'),
#   Decimal('39.49698537'),
#   20),
#  (986,
#   '20/02/2018 05:56:30',
#   20,
#   0,
#   '240_CAMP_DEL_TURIA_AVDA_CORTES_VALENCIANAS',
#   Decimal('-0.401545859'),
#   Decimal('39.49500436'),
#   20),
#  (987,
#   '20/02/2018 05:56:30',
#   6,
#   8,
#   '184_CALLE_BOMBER_RAMON_DUART',
#   Decimal('-0.365568699'),
#   Decimal('39.45278221'),
#   15),
#  (988,
#   '20/02/2018 05:56:30',
#   0,
#   15,
#   '241_VALL_DE_ALBAIDA_PEATONAL',
#   Decimal('-0.401888866'),
#   Decimal('39.49297835'),
#   15),
#  (989,
#   '20/02/2018 05:56:30',
#   2,
#   13,
#   '242_LA_SAFOR_AVDA_MAESTRO_RODRIGO',
#   Decimal('-0.404195874'),
#   Decimal('39.48790734'),
#   15),
#  (990,
#   '20/02/2018 05:56:30',
#   4,
#   11,
#   '269_CAMPAMENTO_81',
#   Decimal('-0.426261981'),
#   Decimal('39.49990739'),
#   15),
#  (991,
#   '20/02/2018 05:56:30',
#   0,
#   40,
#   '088_AVDA. BLASCO IBAÑEZ 3',
#   Decimal('-0.36114066'),
#   Decimal('39.47751228'),
#   40),
#  (992,
#   '20/02/2018 05:56:30',
#   21,
#   0,
#   '099_AVDA. BLASCO IBAÑEZ 8',
#   Decimal('-0.340482549'),
#   Decimal('39.47134425'),
#   21),
#  (993,
#   '20/02/2018 05:56:30',
#   20,
#   0,
#   '100_AVDA. BLASCO IBAÑEZ 9',
#   Decimal('-0.338148532'),
#   Decimal('39.47163425'),
#   20),
#  (994,
#   '20/02/2018 05:56:30',
#   30,
#   0,
#   '101_AVDA. BLASCO IBAÑEZ 10',
#   Decimal('-0.334359511'),
#   Decimal('39.47006824'),
#   30),
#  (995,
#   '20/02/2018 05:56:30',
#   10,
#   10,
#   '102_AVDA.RAMON LLUL',
#   Decimal('-0.346718585'),
#   Decimal('39.47583327'),
#   20),
#  (996,
#   '20/02/2018 05:56:30',
#   15,
#   0,
#   '103_RUBEN DARIO',
#   Decimal('-0.352369612'),
#   Decimal('39.47845328'),
#   15),
#  (997,
#   '20/02/2018 05:56:30',
#   4,
#   15,
#   '104_ALBALAT DELS TARONGERS',
#   Decimal('-0.34727358'),
#   Decimal('39.47838628'),
#   20),
#  (998,
#   '20/02/2018 05:56:30',
#   7,
#   8,
#   '185_AVDA_AUSIAS_MARCH',
#   Decimal('-0.370501719'),
#   Decimal('39.4500442'),
#   15),
#  (999,
#   '20/02/2018 05:56:30',
#   1,
#   29,
#   '105_AVDA. DE LOS NARANJOS',
#   Decimal('-0.344518562'),
#   Decimal('39.47769027'),
#   30),
#  (1000,
#   '20/02/2018 05:56:30',
#   11,
#   14,
#   '106_AVDA. DE LOS NARANJOS',
#   Decimal('-0.34138555'),
#   Decimal('39.47674427'),
#   25),
#  ...]

# %% [markdown]
# <b>3. </b> Instructions:<br>
# - Connect to the dq database as the user dq
# - Write a SQL query that creates a table called users in the dq database, with the following columns and data types:
# - id -- integer data type, and is a primary key.
# - email -- text data type.
# - name -- text data type.
# - address -- text data type.
# - Execute the query using the execute method.
# - Don't close the connection.

# %%
conn = psycopg2.connect("dbname=valenbisi2018 user=nmolivo")
cur = conn.cursor()
cur.execute('CREATE TABLE vbstatic2 (id BIGSERIAL PRIMARY KEY, update VARCHAR(255), available INT, free INT, name VARCHAR(255), long NUMERIC, lat NUMERIC, total INT)');
#using vbstatic2 because I already created vbstatic using the CL. See Markdown document.

# %% [markdown]
# <b>4.</b> Instructions:<br>
# - Connect to the dq database as the user dq.
# - Write a SQL query that creates a table called users in the dq database, with the following columns and data types:
# - id -- integer data type, and is a primary key.
# - email -- text data type.
# - name -- text data type.
# - address -- text data type.
# - Execute the query using the execute method.
# - Use the commit method on the Connection object to apply the changes in the transaction to the database.
# - Close the Connection.

# %% [markdown]
# >Whenever we open a Connection in psycopg2, a new transaction will automatically be created.
# >All queries run up until the <a href = "http://initd.org/psycopg/docs/connection.html#connection.commit"><b>commit()</b></a> method is called. When a commit is called, the PostgreSQL
# >engine will run all the queries at once.
#
# >If we don't want to apply the changes in the transaction block, we can call the <b>rollback()</b>
# >method to remove the transaction. Not calling either commit or rollback will cause the
# >transaction to stay in a pending state, and will result in the changes not being applied to
# >the database.
# >
# >DataQuest

# %%
conn = psycopg2.connect("dbname=valenbisi2018 user = nmolivo")
cur = conn.cursor()
cur.execute('CREATE TABLE vbstatic2 (id BIGSERIAL PRIMARY KEY, \
            update VARCHAR(255), \
            available INT, \
            free INT, name VARCHAR(255), \
            long NUMERIC, \
            lat NUMERIC, \
            total INT)');
conn.commit()
conn.close()

# %% [markdown]
# <font color = 'blue'>If you're new to Python/Jupyter, know that the forward slashes allow me to continue the code on the following line, purely for readability. If you are replicating similar work, you can make the SQL command a single line with no slashes, or if you do find the multiple lines helpful, make sure no spaces follow the forward slash.</font>

# %% [markdown]
# <b>5. </b> Instructions
# - Import the csv module.
# - Load the user_accounts.csv using the csv module
# - Connect to the dq database as the user dq
# - Execute the insert query on the users table using the execute method from the example above.
# - Insert every row from the user_accounts.csv file and skip the header row.
# - Fetch all the results from the users table and assign it to the variable users.
# - Close the Connection using the close method.

# %% [markdown]
# >While `INSERT` works, it's best used when you are trying to insert individual rows.

# %%
import csv
with open('vb_table.csv') as f:
    reader = csv.reader(f, delimiter=",")
    next(reader)
    rows = [row for row in reader]

conn = psycopg2.connect("dbname=valenbisi2018 user=nmolivo")
cur = conn.cursor()

for row in rows:
    cur.execute("INSERT INTO vbstatic2 VALUES (%s, %s, %s, %s, %s, %s, %s, %s)", row)
conn.commit()

cur.execute('SELECT * FROM vbstatic2')
users = cur.fetchall()
conn.close()

# %% [markdown]
# <b>6.</b> Instructions
# - Connect to the dq database as the user dq
# - Load the user_accounts.csv using with open(...) as f.
# - Skip the header row.
# - Using the copy_from method, copy the file into the database.
# - Fetch all the results from the users table and assign it to the variable users.
# - Close the Connection using the close method.

# %% [markdown]
# <font color = 'blue'>Since this is a slightly different method of performing the same task as before, I will not run it:</font>
# ```python
# conn = psycopg2.connect("dbname=valenbisi2018 user=nmolivo")
# cur = conn.cursor()
#
# with open('vb_table.csv') as f:
#     next(f)
#     cur.copy_from(f, 'vbstatic2', sep=',')
# conn.commit()
#
# cur.execute('SELECT * FROM vbstatic2')
# data = cur.fetchall()
# conn.close()
# ```
